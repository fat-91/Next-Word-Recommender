# %% [markdown]
# <a href="https://colab.research.google.com/github/fat-91/test/blob/main/Next_word_Recommender_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Steps to build the next word recommender system
#
# 1. Loading and exploring the dataset
# 2. Creating N-grams of the dialogue
# 3. Building the N-gram Language Model
# 4. Predicting the next word using N-gram Language Model

# %% [markdown]
# ## 1. Loading and exploring the dataset

# %%
# loading the required libraries
import pandas as pd
import numpy as np
import re
import pickle
import random
from tqdm import tqdm

# %%
# mounting the drive
#from google.colab import drive
#drive.mount('/content/drive')

# %%
# open text file and read in data
import pandas as pd
df = pd.read_csv('sample_reuters_dataset.csv')  # Replace 'dialogs_dataset.csv' with your actual file name
print(df.head())  # This will display the first 5 rows
# Out:
#    sentence_number                                      sentence_text
# 0                0  ASIAN EXPORTERS FEAR DAMAGE FROM U . S .- JAPA...
# 1                1  They told Reuter correspondents in Asian capit...
# 2                2  But some exporters said that while the conflic...
# 3                3  The U . S . Has said it will impose 300 mln dl...
# 4                4  Unofficial Japanese estimates put the impact o...

# %%
sentences = df['sentence_text'].tolist()  # Extract the 'sentence_text' column and convert it into a list

# %%
random.sample(sentences, 10)
# Out:
# ['However , the intervention failed to boost the U . S . Currency significantly from the 142 . 20 yen level , they added .',
#  'MAGMA RAISES COPPER PRICE 0 . 25 CT TO 65 . 75 CTS Magma Copper Co , a subsidiary of Newmont Mining Corp , said it is raising its copper cathode price by 0 . 25 cent to 65 . 75 cents a lb , effective immediately .',
#  'And resorting to higher interest rates could lead to recession , he said .',
#  'It is expected to be considered by the full Senate by the end of the summer .',
#  'J . Terence Murray , chairman and president of Fleet Financial , said , " Fleet \' s mortgage banking activities in particular continued to produce signficant income increases ( in the first quarter )."',
#  "The February increase was less than Janauary ' s 0 . 4 pct increase but slightly above the average for the later months of 1986 .",
#  'The Japanese shareholders , the Overseas Economic Cooperation Fund and 12 companies , are to invest another 24 billion yen raising capitalisation to 147 billion yen .',
#  'MARINE MIDLAND BANKS INC 1ST QTR 1 . 74 DLRS VS 1 . 89 DLRS',
#  'FRENCH AID TO TOGO TO HELP COFFEE , COCOA TREES France is to provide Togo with 475 mln cfa francs of aid for a range of projects that include development of the coffee and cocoa industries and reafforestation in the south of the country , official sources said .',
#  'He said the ministry sent a proposal today to the cabinet that the tariffs on such products as cosmetics , bicycles , apples , radios , garments , soybeans and television sets be cut by between five and 50 pct .']

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# If you haven't already downloaded these, run once:
# nltk.download('stopwords')
# nltk.download('wordnet')
# nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

sentences_clean = []

for i in sentences:
    # Remove everything except alphabets, apostrophes, and white spaces
    i = re.sub(r"[^a-zA-Z' ]", '', i)

    # Convert text to lowercase and normalize whitespace
    i = i.lower().strip()
    i = re.sub(r'\s+', ' ', i)

    # Tokenize the sentence into words
    words = i.split()

    # Lemmatize and remove stopwords
    cleaned_words = [
        lemmatizer.lemmatize(word)
        for word in words
        ##if word not in stop_words
    ]

    # Join words back into a cleaned sentence
    cleaned_sentence = ' '.join(cleaned_words)

    # Append to the cleaned sentences list
    sentences_clean.append(cleaned_sentence)

# Check results
print(sentences_clean[:5])  # print first 5 cleaned sentences for example
# Out:
# ["asian exporter fear damage from u s japan rift mounting trade friction between the u s and japan ha raised fear among many of asia ' s exporting nation that the row could inflict far reaching economic damage businessmen and official said", 'they told reuter correspondent in asian capital a u s move against japan might boost protectionist sentiment in the u s and lead to curb on american import of their product', "but some exporter said that while the conflict would hurt them in the long run in the short term tokyo ' s loss might be their gain", "the u s ha said it will impose mln dlrs of tariff on import of japanese electronics good on april in retaliation for japan ' s alleged failure to stick to a pact not to sell semiconductor on world market at below cost", 'unofficial japanese estimate put the impact of the tariff at billion dlrs and spokesman for major electronics firm said they would virtually halt export of product hit by the new tax']

# %%
random.sample(sentences_clean, 10)
# Out:
# ['the company said shareholder at the annual meeting approved an increase in authorized common share to mln from mln and a name change to alfa corp',
#  "uae trade current account surplus narrow the united arab emirate uae recorded a trade surplus of billion dirham narrowing from billion in the central bank ' s latest bulletin show",
#  'while the automobile industry remained unchanged from previously boosted level consumer good production grew and wa expected to accelerate except in the area of domestic appliance',
#  'the sixth ita will expire at the end of june unless a two third majority of member vote for an extension',
#  'group raise computer memory lt cmin stake a shareholder group led by far hill n j investor natalie koether said it raised it stake in computer memory inc to share or pct of the total outstanding from share or pct',
#  'jun jun',
#  'the smelter also produced cadmium bismuth and indium',
#  'retailer are not planning for much inventory are being kept lean markdowns are lower than last year but sale are coming through anyway said cj analyst harry mortner',
#  "lex ' s existing automotive interest include volvo concessionaire the sole importer of volvo car and part into the u k lex said the turnover for sears motor group in the year to december wa mln stg and that at the date of the acquisition the group had about mln stg in external borrowing",
#  'china face extended sorghum shortage china will be short of sorghum in for the sixth successive year because high production cost and low profit discourage farmer from growing it the china daily business weekly said']

# %%
from sklearn.model_selection import train_test_split

# Split into train and test (80/20)
train_sentences, test_sentences = train_test_split(sentences_clean, test_size=0.2, random_state=42)

# Check sizes
print(f"Training sentences: {len(train_sentences)}")
print(f"Testing sentences: {len(test_sentences)}")
# Out:
# Training sentences: 8000
# Testing sentences: 2000

# %%
# creating the vocabulary
# get list of all the words
all_words = " ".join(train_sentences).split()

words_dict = {}

# add word-count pair to the dictionary
for word in all_words:
    # check if the word is already in dictionary
    if word in words_dict:
        # increment count of word by 1
        words_dict[word] = words_dict[word] + 1
    else:
        # add the word to dictionary with count 1
        words_dict[word] = 1

# %%
# word dictionary
words_dict
# Out:
# {'tranche': 4,
#  'increased': 59,
#  'tonne': 503,
#  'south': 100,
#  'korea': 33,
#  'added': 188,
#  'possible': 60,
#  'destination': 14,
#  'showa': 5,
#  'denko': 3,
#  'export': 343,
#  'aluminium': 19,
#  'casting': 2,
#  'equipment': 34,
#  'lt': 1200,
#  'ltd': 212,
#  'said': 3701,
#  'exporting': 9,
#  'billet': 1,
#  'technology': 49,
#  'country': 194,
#  'recently': 35,
#  'begun': 6,
#  'smelting': 5,
#  'note': 232,
#  'company': 840,
#  "'": 1683,
#  'full': 69,
#  'name': 47,
#  'gebrueder': 2,
#  'sulzer': 2,
#  'ag': 12,
#  'sulz': 1,
#  'z': 9,
#  'romero': 8,
#  'philippine': 26,
#  'end': 238,
#  'five': 208,
#  'year': 1113,
#  'coconut': 17,
#  'production': 229,
#  'cycle': 3,
#  'showed': 43,
#  'tended': 2,
#  'fall': 106,
#  'two': 368,
#  'successive': 3,
#  'good': 110,
#  'harvest': 19,
#  'lme': 18,
#  'warehouse': 9,
#  'stock': 455,
#  'near': 38,
#  'low': 69,
#  'fallen': 11,
#  'steadily': 4,
#  'record': 152,
#  'high': 123,
#  'reached': 46,
#  'february': 150,
#  'many': 43,
#  'major': 164,
#  'nation': 81,
#  'yesterday': 133,
#  'intervened': 8,
#  'heavily': 9,
#  'aid': 28,
#  'dlr': 188,
#  'miyazawa': 26,
#  'transaction': 76,
#  'structured': 3,
#  'merger': 94,
#  'liberty': 14,
#  'duly': 1,
#  'formed': 24,
#  'unit': 175,
#  'equimark': 5,
#  'ec': 136,
#  'failed': 15,
#  'follow': 10,
#  'consultation': 8,
#  'procedure': 18,
#  'laid': 3,
#  'lome': 1,
#  'convention': 1,
#  'regulates': 2,
#  'relation': 12,
#  'acp': 8,
#  'state': 207,
#  'bloc': 5,
#  'move': 105,
#  'could': 234,
#  'affect': 19,
#  'trade': 447,
#  'side': 15,
#  'dollar': 328,
#  'fell': 98,
#  'yen': 155,
#  'despite': 60,
#  'central': 152,
#  'bank': 614,
#  'intervention': 62,
#  'dealer': 131,
#  'george': 9,
#  'wimpey': 4,
#  'say': 197,
#  'benefit': 31,
#  'restructuring': 40,
#  'seen': 56,
#  'plc': 85,
#  'wmpy': 2,
#  'l': 57,
#  'outlook': 20,
#  'looked': 4,
#  'encouraging': 4,
#  'realised': 2,
#  'continuing': 45,
#  'dangerous': 6,
#  'go': 35,
#  'retaliatory': 4,
#  'route': 9,
#  'lead': 74,
#  'retaliation': 17,
#  'restriction': 23,
#  'indication': 9,
#  'u': 895,
#  'ship': 45,
#  'loaded': 2,
#  'raw': 21,
#  'sugar': 98,
#  'awaiting': 7,
#  'silvertown': 2,
#  'discharged': 2,
#  'tate': 5,
#  'lyle': 4,
#  'jeffrey': 3,
#  'leeds': 2,
#  'chemical': 61,
#  'convinced': 5,
#  'fed': 133,
#  'tightening': 11,
#  'policy': 139,
#  'prospect': 22,
#  'significant': 31,
#  'improvement': 29,
#  'unemployment': 29,
#  'situation': 24,
#  'next': 132,
#  'month': 333,
#  'average': 127,
#  'rate': 542,
#  'expected': 228,
#  'stabilize': 15,
#  'pct': 1509,
#  'similar': 32,
#  'last': 516,
#  'woodstock': 5,
#  'holding': 85,
#  'mln': 2521,
#  'every': 12,
#  'half': 88,
#  'week': 344,
#  'american': 111,
#  'dy': 3,
#  'salmonellosis': 2,
#  'complication': 1,
#  'arising': 2,
#  'incidence': 2,
#  'poisoning': 3,
#  'poultry': 21,
#  'past': 49,
#  'several': 63,
#  'self': 5,
#  'contained': 13,
#  'part': 88,
#  'overall': 30,
#  'group': 300,
#  'trans': 5,
#  'lux': 4,
#  'connecticut': 3,
#  'concern': 39,
#  'lease': 3,
#  'teleprinter': 1,
#  'display': 3,
#  'brokerage': 9,
#  'office': 45,
#  'airport': 6,
#  'public': 62,
#  'place': 28,
#  'crushing': 4,
#  'would': 747,
#  'commence': 3,
#  'labasa': 1,
#  'penang': 1,
#  'mill': 24,
#  'june': 197,
#  'lautoka': 2,
#  'rarawai': 1,
#  'brooklyn': 11,
#  'union': 94,
#  'fourth': 35,
#  'largest': 64,
#  'gas': 134,
#  'utility': 15,
#  'united': 136,
#  'purchased': 20,
#  'supply': 168,
#  'spot': 34,
#  'non': 83,
#  'contract': 89,
#  'market': 542,
#  'proportion': 2,
#  'estimated': 80,
#  'much': 70,
#  'higher': 134,
#  'analyst': 188,
#  'roth': 3,
#  'still': 95,
#  'interested': 15,
#  'acquiring': 18,
#  'turco': 2,
#  'atcor': 7,
#  'reviewing': 5,
#  'option': 37,
#  'potential': 22,
#  'buyer': 44,
#  'expressed': 15,
#  'interest': 237,
#  'consumer': 102,
#  'product': 210,
#  'business': 165,
#  'represent': 7,
#  'first': 371,
#  'victim': 3,
#  'price': 631,
#  'natural': 43,
#  'resource': 38,
#  'according': 41,
#  'system': 121,
#  'zimmerman': 9,
#  'mobil': 14,
#  'mob': 5,
#  'north': 34,
#  'sea': 7,
#  'find': 17,
#  'corp': 500,
#  'wildcat': 1,
#  'well': 83,
#  'block': 20,
#  'british': 61,
#  'flowed': 2,
#  'cubic': 18,
#  'foot': 20,
#  'per': 274,
#  'day': 227,
#  'depth': 3,
#  'asset': 140,
#  'uam': 1,
#  'completes': 23,
#  'acquisition': 190,
#  'management': 103,
#  'completed': 50,
#  'rice': 50,
#  'hall': 4,
#  'james': 28,
#  'associate': 43,
#  'san': 26,
#  'diego': 4,
#  'undisclosed': 34,
#  'term': 173,
#  'includes': 102,
#  'lazere': 3,
#  'loan': 194,
#  'portfolio': 4,
#  'including': 78,
#  'miami': 4,
#  'finland': 6,
#  'neste': 3,
#  'oy': 3,
#  'whose': 14,
#  'turnover': 27,
#  'billion': 857,
#  'dlrs': 1704,
#  'extensive': 4,
#  'experience': 8,
#  'mtbe': 6,
#  'arrangement': 22,
#  'financing': 47,
#  'yet': 43,
#  'made': 139,
#  'assurance': 8,
#  'received': 56,
#  'hmo': 2,
#  'asked': 58,
#  'japan': 344,
#  'committed': 8,
#  'fresh': 18,
#  'measure': 68,
#  'statement': 144,
#  'exceptional': 7,
#  'among': 31,
#  'seven': 115,
#  'appreciated': 2,
#  'currency': 176,
#  'largely': 13,
#  'stable': 28,
#  'initial': 28,
#  'distribution': 28,
#  'take': 120,
#  'form': 30,
#  'dividend': 123,
#  'cumulative': 23,
#  'redeemable': 5,
#  'retractable': 2,
#  'class': 24,
#  'series': 39,
#  'preferred': 61,
#  'share': 808,
#  'entitling': 2,
#  'holder': 30,
#  'monthly': 30,
#  'floating': 8,
#  'prime': 63,
#  'retraction': 1,
#  'aristech': 3,
#  'ar': 1,
#  'st': 223,
#  'qtr': 373,
#  'shr': 500,
#  'estimate': 71,
#  'right': 75,
#  'chairman': 108,
#  'chief': 33,
#  'executive': 52,
#  'officer': 32,
#  'thomas': 4,
#  'marshall': 9,
#  'fiscal': 68,
#  'earnings': 145,
#  'hint': 3,
#  'announcement': 46,
#  'might': 49,
#  'may': 435,
#  'buy': 163,
#  'wheat': 148,
#  'valued': 11,
#  'april': 376,
#  'august': 31,
#  'port': 47,
#  'september': 39,
#  'department': 151,
#  'magellan': 7,
#  'disclose': 12,
#  'agreement': 248,
#  'fee': 21,
#  'trust': 48,
#  'banking': 41,
#  'service': 92,
#  'rose': 191,
#  'earlier': 135,
#  'adam': 6,
#  'express': 6,
#  'co': 303,
#  'adx': 1,
#  'march': 246,
#  'v': 1849,
#  'shrs': 134,
#  'lastest': 1,
#  'capital': 89,
#  'gain': 115,
#  'ct': 1027,
#  'december': 74,
#  'china': 91,
#  'resume': 16,
#  'ussr': 17,
#  'repair': 9,
#  'gap': 10,
#  'resumed': 4,
#  'soviet': 40,
#  'break': 16,
#  'caused': 32,
#  'ideological': 1,
#  'split': 63,
#  'seasonally': 28,
#  'adjusted': 74,
#  'index': 39,
#  'input': 6,
#  'rise': 227,
#  'rash': 1,
#  'advertising': 5,
#  'solicit': 3,
#  'new': 396,
#  'helped': 16,
#  'homebuyers': 1,
#  'become': 36,
#  'even': 39,
#  'choosier': 1,
#  'lender': 11,
#  'concede': 1,
#  'forced': 13,
#  'undercut': 2,
#  'totally': 3,
#  'unadjusted': 12,
#  'figure': 141,
#  'show': 63,
#  'deficit': 186,
#  'revised': 38,
#  'compared': 131,
#  'statistic': 34,
#  'producer': 102,
#  'heavy': 33,
#  'heating': 13,
#  'oil': 487,
#  'liquefied': 3,
#  'coffee': 59,
#  'cheaper': 6,
#  'xebec': 6,
#  'also': 329,
#  'expects': 86,
#  'revenue': 82,
#  'total': 238,
#  'ncr': 9,
#  'achieving': 2,
#  'recuperation': 2,
#  'credit': 153,
#  'cannot': 22,
#  'done': 19,
#  'overnight': 16,
#  'azpurua': 10,
#  'television': 21,
#  'interview': 18,
#  'commonwealth': 13,
#  'cut': 234,
#  'australia': 47,
#  'lower': 133,
#  'lending': 14,
#  'effective': 71,
#  'progress': 19,
#  'main': 34,
#  'sector': 63,
#  'except': 14,
#  'remain': 48,
#  'present': 34,
#  'level': 150,
#  'report': 189,
#  'fluor': 3,
#  'applied': 10,
#  'engineering': 6,
#  'construct': 2,
#  'modular': 1,
#  'section': 7,
#  'deliver': 5,
#  'ge': 6,
#  'waterford': 1,
#  'n': 69,
#  'silicone': 1,
#  'division': 60,
#  'plant': 74,
#  'merchant': 14,
#  'fear': 16,
#  'large': 59,
#  'tonnage': 8,
#  'delivered': 8,
#  'future': 95,
#  'possibly': 16,
#  'disrupt': 1,
#  'physical': 8,
#  'franc': 72,
#  'carry': 18,
#  'warrant': 29,
#  'today': 225,
#  'itc': 16,
#  'ruling': 26,
#  'consistent': 15,
#  'commerce': 34,
#  'final': 40,
#  'activates': 1,
#  'anti': 16,
#  'dumping': 15,
#  'duty': 19,
#  'import': 243,
#  'brazilian': 22,
#  'frozen': 12,
#  'concentrated': 7,
#  'orange': 33,
#  'juice': 22,
#  'stephen': 6,
#  'vastagh': 4,
#  'investigator': 1,
#  'ministry': 92,
#  'tf': 2,
#  'forthcoming': 2,
#  'sell': 132,
#  'meant': 6,
#  'third': 61,
#  'government': 246,
#  'programme': 11,
#  'less': 73,
#  'nine': 99,
#  'institute': 59,
#  'issued': 38,
#  'joint': 46,
#  'spring': 19,
#  'three': 221,
#  'kiel': 2,
#  'hamburg': 4,
#  'essen': 2,
#  'forecast': 94,
#  'gnp': 36,
#  'west': 177,
#  'berlin': 7,
#  'munich': 3,
#  'predicted': 29,
#  'one': 418,
#  'westcoast': 3,
#  'enable': 7,
#  'apply': 8,
#  'accumulated': 4,
#  'tax': 250,
#  'pool': 4,
#  'agip': 9,
#  'canada': 127,
#  'enhance': 6,
#  'cash': 129,
#  'flow': 21,
#  'acquired': 77,
#  'property': 40,
#  'proxy': 5,
#  'material': 54,
#  'maioled': 1,
#  'quarter': 315,
#  'speech': 10,
#  'prepared': 20,
#  'delivery': 55,
#  'plan': 203,
#  'protect': 22,
#  'kuwaiti': 19,
#  'tanker': 17,
#  'iranian': 22,
#  'attack': 14,
#  'reagan': 74,
#  'people': 30,
#  'aware': 4,
#  'alone': 9,
#  'protected': 10,
#  'pointed': 6,
#  'depressed': 8,
#  'reason': 37,
#  'current': 190,
#  'weakness': 16,
#  'economy': 126,
#  'later': 49,
#  'stronger': 7,
#  'domestic': 129,
#  'demand': 142,
#  'compensate': 5,
#  'setback': 2,
#  'happy': 4,
#  'brought': 10,
#  'forward': 24,
#  'mark': 102,
#  'planned': 42,
#  'january': 88,
#  'beginning': 24,
#  'faced': 5,
#  'political': 28,
#  'constraint': 5,
#  'getting': 8,
#  'upper': 8,
#  'house': 74,
#  'german': 94,
#  'parliament': 5,
#  'quoted': 30,
#  'stg': 176,
#  'midsession': 2,
#  'represents': 10,
#  'decline': 69,
#  'buffer': 29,
#  'aim': 10,
#  'keep': 29,
#  'within': 48,
#  'pre': 24,
#  'set': 123,
#  'range': 58,
#  'buying': 44,
#  'selling': 30,
#  'bentsen': 5,
#  'coordinated': 2,
#  'debt': 109,
#  'latin': 4,
#  'help': 71,
#  'ease': 17,
#  'protectionist': 15,
#  'pressure': 59,
#  'industrial': 92,
#  'proposal': 94,
#  'objective': 10,
#  'maintain': 29,
#  'idc': 4,
#  'official': 285,
#  'declined': 48,
#  'specify': 6,
#  'talk': 94,
#  'economist': 79,
#  'spending': 38,
#  'target': 54,
#  'rand': 9,
#  'budgeted': 4,
#  'around': 134,
#  'validly': 4,
#  'tendered': 18,
#  'represented': 7,
#  'outstanding': 84,
#  'supermarket': 9,
#  'general': 77,
#  'america': 46,
#  'retain': 8,
#  'refusal': 4,
#  'ansett': 8,
#  'offered': 42,
#  'sale': 408,
#  'choke': 2,
#  'modest': 21,
#  'economic': 197,
#  'expansion': 30,
#  'threaten': 4,
#  'recession': 15,
#  'bought': 70,
#  'band': 15,
#  'eight': 81,
#  'four': 145,
#  'paid': 53,
#  'assumption': 11,
#  'liability': 9,
#  'maize': 34,
#  'sown': 10,
#  'hectare': 30,
#  'season': 63,
#  'hopefully': 2,
#  'trend': 17,
#  'richardson': 2,
#  'greenshields': 1,
#  'susan': 1,
#  'clark': 8,
#  'toronto': 9,
#  'investment': 150,
#  'firm': 139,
#  'raise': 101,
#  'tvx': 3,
#  'tvxg': 2,
#  'stake': 130,
#  'wedge': 1,
#  'inc': 577,
#  'houston': 15,
#  'raised': 51,
#  'broadcast': 5,
#  'common': 128,
#  'call': 51,
#  'sino': 1,
#  'chilean': 1,
#  'venture': 44,
#  'paper': 23,
#  'european': 105,
#  'mediterranean': 3,
#  'area': 79,
#  'rig': 11,
#  'utilization': 3,
#  'ago': 108,
#  'upset': 1,
#  'compounded': 1,
#  'news': 44,
#  'sterling': 18,
#  'england': 32,
#  'look': 24,
#  'likely': 86,
#  'gilt': 4,
#  'offset': 26,
#  'impact': 46,
#  'money': 147,
#  'bp': 15,
#  'came': 18,
#  'result': 138,
#  'review': 37,
#  'occasioned': 1,
#  'substantial': 31,
#  'change': 100,
#  'lpg': 2,
#  'congressional': 23,
#  'leader': 24,
#  'complain': 1,
#  'consulted': 2,
#  'put': 55,
#  'flag': 12,
#  'charged': 9,
#  'iran': 22,
#  'iraq': 32,
#  'war': 25,
#  'told': 198,
#  'al': 8,
#  'riyadh': 3,
#  'newspaper': 33,
#  'saudi': 39,
#  'arabia': 26,
#  'follows': 34,
#  'balanced': 7,
#  'petroleum': 74,
#  'expanded': 6,
#  'baht': 3,
#  'deputy': 12,
#  'representative': 34,
#  'michael': 13,
#  'smith': 9,
#  'makoto': 2,
#  'kuroda': 6,
#  'minister': 152,
#  'international': 185,
#  'industry': 248,
#  'miti': 12,
#  'due': 130,
#  'meet': 51,
#  'washington': 70,
#  'effort': 48,
#  'dispute': 22,
#  'legislation': 20,
#  'supported': 9,
#  'congress': 39,
#  'democratic': 16,
#  'republican': 8,
#  'leadership': 3,
#  'administration': 35,
#  'required': 24,
#  'defense': 24,
#  'secretary': 41,
#  'caspar': 1,
#  'weinberger': 1,
#  'provide': 32,
#  'enactment': 1,
#  'warship': 4,
#  'persian': 1,
#  'gulf': 72,
#  'questioned': 4,
#  'whether': 35,
#  'based': 116,
#  'entertainment': 15,
#  'marketing': 58,
#  'founded': 3,
#  'former': 22,
#  'electronics': 20,
#  'retailer': 13,
#  'buinesses': 1,
#  'primarily': 10,
#  'wholesale': 14,
#  'distributor': 10,
#  'expertise': 1,
#  'retailing': 5,
#  'merely': 3,
#  'trying': 20,
#  'drive': 19,
#  'crazy': 30,
#  'eddie': 31,
#  'already': 66,
#  'owns': 33,
#  'federal': 114,
#  'reserve': 213,
#  'board': 144,
#  'paul': 15,
#  'volcker': 20,
#  'repeatedly': 7,
#  'cutting': 17,
#  'red': 22,
#  'ink': 3,
#  'long': 90,
#  'way': 46,
#  'reduce': 64,
#  'massive': 11,
#  'downward': 10,
#  'value': 96,
#  'profit': 342,
#  'almost': 25,
#  'consolidated': 24,
#  'net': 882,
#  'swiss': 34,
#  'drop': 48,
#  'cardenas': 2,
#  'cent': 83,
#  'lb': 33,
#  'october': 45,
#  'support': 60,
#  'jorge': 2,
#  'manager': 45,
#  'colombia': 18,
#  'national': 145,
#  'grower': 13,
#  'federation': 13,
#  'little': 50,
#  'reaction': 13,
#  'comex': 5,
#  'limit': 42,
#  'removal': 9,
#  'elimination': 7,
#  'precious': 4,
#  'metal': 42,
#  'trading': 126,
#  'commodity': 65,
#  'exchange': 216,
#  'york': 75,
#  'appears': 12,
#  'effect': 42,
#  'mercer': 6,
#  'operating': 78,
#  'goodyear': 14,
#  'repurchase': 59,
#  'fend': 3,
#  'sir': 4,
#  'goldsmith': 4,
#  'hostile': 14,
#  'takeover': 81,
#  'bid': 137,
#  'lot': 15,
#  'given': 53,
#  'lindberg': 1,
#  'lind': 1,
#  'avg': 133,
#  'proceeds': 25,
#  'discount': 62,
#  'penalty': 5,
#  'rather': 24,
#  'guiding': 2,
#  'since': 117,
#  'advance': 14,
#  'currently': 48,
#  'used': 60,
#  'liquidity': 24,
#  'ample': 4,
#  'trader': 120,
#  'london': 50,
#  'outcome': 10,
#  'tender': 131,
#  'hard': 28,
#  'predict': 6,
#  'award': 10,
#  'placing': 6,
#  'borg': 41,
#  'warner': 44,
#  'participant': 5,
#  'position': 70,
#  'reuter': 21,
#  'k': 84,
#  'assistance': 17,
#  'provided': 19,
#  'morning': 32,
#  'session': 20,
#  'takashi': 4,
#  'ishihara': 6,
#  'committee': 65,
#  'development': 80,
#  'accord': 51,
#  'prevent': 24,
#  'rising': 60,
#  'extent': 7,
#  'fewer': 10,
#  'sdhares': 1,
#  'offer': 295,
#  'stockholder': 22,
#  'receive': 42,
#  'combination': 17,
#  'caesar': 9,
#  'unilever': 10,
#  'seek': 29,
#  'stauffer': 5,
#  'nv': 6,
#  'un': 3,
#  'prospectus': 2,
#  'banker': 63,
#  'goldman': 2,
#  'sachs': 2,
#  'seeking': 36,
#  'recent': 77,
#  'chesebrough': 5,
#  'pond': 2,
#  'spokesman': 134,
#  'italian': 23,
#  'daily': 56,
#  'la': 18,
#  'repubblica': 1,
#  'gemina': 2,
#  'lira': 29,
#  'shareholding': 3,
#  'hick': 4,
#  'haas': 7,
#  'spectradyne': 4,
#  'spdy': 1,
#  'fund': 120,
#  'spi': 1,
#  'consisting': 4,
#  'acadia': 1,
#  'partner': 58,
#  'lp': 5,
#  'commitment': 48,
#  'senior': 30,
#  'needed': 43,
#  'complete': 18,
#  'proposed': 84,
#  'security': 150,
#  'samjens': 13,
#  'lawyer': 13,
#  'discounted': 4,
#  'trip': 7,
#  'attempt': 21,
#  'farm': 74,
#  'key': 44,
#  'gatt': 18,
#  'member': 70,
#  'addition': 33,
#  'sealy': 7,
#  'redeemed': 1,
#  'held': 87,
#  'michigan': 6,
#  'thus': 12,
#  'increasing': 29,
#  'fargo': 9,
#  'wfc': 1,
#  'deposit': 70,
#  'filing': 41,
#  'wet': 3,
#  'barrel': 104,
#  'unprofitable': 3,
#  'world': 142,
#  'cocoa': 60,
#  'interesting': 4,
#  'commented': 1,
#  'delegate': 10,
#  'representing': 10,
#  'cpa': 6,
#  'cabinet': 14,
#  'give': 48,
#  'approval': 61,
#  'thursday': 12,
#  'tariff': 95,
#  'implemented': 6,
#  'starting': 19,
#  'cominco': 23,
#  'clt': 3,
#  'reject': 11,
#  'steelworker': 10,
#  'local': 57,
#  'strike': 41,
#  'rejected': 26,
#  'tentative': 6,
#  'g': 73,
#  'affirmed': 2,
#  'appropriate': 17,
#  'carefully': 5,
#  'worded': 1,
#  'boost': 40,
#  'particularly': 25,
#  'uccel': 20,
#  'shareholder': 140,
#  'computer': 84,
#  'approximately': 13,
#  'case': 39,
#  'related': 26,
#  'airline': 13,
#  'awal': 2,
#  'party': 46,
#  'voicing': 1,
#  'opposition': 14,
#  'purchase': 102,
#  'issue': 93,
#  'sears': 9,
#  'lex': 10,
#  'ordinary': 23,
#  'begin': 50,
#  'time': 121,
#  'prudhoe': 2,
#  'bay': 3,
#  'without': 38,
#  'endangering': 1,
#  'caribou': 1,
#  'wildlife': 2,
#  'dome': 133,
#  'encor': 6,
#  'budget': 89,
#  'portrayed': 1,
#  'mildly': 1,
#  'contractionary': 1,
#  'doubling': 3,
#  'nominal': 7,
#  'dinar': 12,
#  'underlying': 20,
#  'back': 44,
#  'late': 39,
#  'second': 65,
#  'period': 151,
#  'ended': 118,
#  'wednesday': 33,
#  'discussed': 10,
#  'problem': 70,
#  'developing': 15,
#  'proceed': 4,
#  ...}

# %%
# prepare a dataframe
words_df = pd.DataFrame({'word':list(words_dict.keys()), 'count':list(words_dict.values())})

# sort words by their count in increasing order
words_df = words_df.sort_values(by = ['count'])

# reset dataframe index
words_df.reset_index(inplace = True, drop=True)

# %%
# words with least frequency
words_df.head()
# Out:
#            word  count
# 0  kuppenheimer      1
# 1      euromark      1
# 2      scarcely      1
# 3     unaltered      1
# 4          elia      1

# %%
# words with highest frequency
words_df.tail()
# Out:
#        word  count
# 10315     '   1683
# 10316  dlrs   1704
# 10317     v   1849
# 10318   mln   2521
# 10319  said   3701

# %%
# vocabulary size
len(words_df)
# Out:
# 10320

# %% [markdown]
# ## 2. Creating N-grams of the dialogue

# %%
# creating an empty dataframe
dataset = pd.DataFrame()

# adding cleaned sentences in the dataframe
dataset['Sentences'] = train_sentences

# first 20 cleaned sentences
dataset.head(20)
# Out:
#                                             Sentences
# 0   tranche increased tonne tonne south korea adde...
# 1   showa denko export aluminium casting equipment...
# 2   note company ' full name gebrueder sulzer ag l...
# 3   romero said philippine end five year coconut p...
# 4   lme warehouse stock near two year low tonne fa...
# 5   many major nation yesterday intervened heavily...
# 6   transaction structured merger liberty duly for...
# 7   said ec failed follow consultation procedure l...
# 8   dollar fell low yen despite central bank inter...
# 9   george wimpey say benefit restructuring seen g...
# 10  ' dangerous go retaliatory route said lead ret...
# 11                                       indication u
# 12  five ship loaded raw sugar awaiting silvertown...
# 13  jeffrey leeds chemical bank convinced fed tigh...
# 14  prospect significant improvement unemployment ...
# 15  woodstock holding company mln dlr state bank w...
# 16  said every two half week american dy salmonell...
# 17      formed self contained part overall group said
# 18  trans lux connecticut concern lease teleprinte...
# 19  crushing would commence labasa penang mill jun...

# %%
# using .split() to get tokens from the sentence
dataset['Sentences'][0].split()
# Out:
# ['tranche',
#  'increased',
#  'tonne',
#  'tonne',
#  'south',
#  'korea',
#  'added',
#  'possible',
#  'destination']

# %%
# function to create unigrams
# taking a sentence as input
def create_unigram(sentence):
    # creating tokens from the sentence
    tokens = sentence.split()
    # empty list to store the unigrams
    unigram_list = []
    # number of unigrams is equal to the number of tokens in the sentence
    for i in range(len(tokens)):
        # appending each unigram in the list
        unigram_list.append(tokens[i:i+1])
    # returning the unigram list for a sentence
    return unigram_list

# %%
# function to create bigrams
def create_bigram(sentence):
    tokens = sentence.split()
    bigram_list = []
    # number of bigrams is one less than the number of tokens in the sentence
    for i in range(len(tokens)-1):
        bigram_list.append(tokens[i:i+2])
    return bigram_list

# %%
# function to create trigrams
def create_trigram(sentence):
    tokens = sentence.split()
    trigram_list = []
    # number of trigrams is two less than the number of tokens in the sentence
    for i in range(len(tokens)-2):
        trigram_list.append(tokens[i:i+3])
    return trigram_list

# %%
# creating unigrams for all the sentences in the dataset
final_unigram = []
# for each sentence
for i in range(dataset.shape[0]):
    # using the defined unigram function to create unigrams
    final_unigram.append(create_unigram(dataset['Sentences'][i]))

# adding the unigram in a seperate column in the dataset
dataset['unigram'] = final_unigram

# %%
# creating bigrams for all the sentences in the dataset
final_bigram = []
for i in range(dataset.shape[0]):
    final_bigram.append(create_bigram(dataset['Sentences'][i]))

dataset['bigram'] = final_bigram

# %%
# creating trigrams for all the sentences in the dataset
final_trigram = []
for i in range(dataset.shape[0]):
    final_trigram.append(create_trigram(dataset['Sentences'][i]))

dataset['trigram'] = final_trigram

# %%
# first 20 rows of the dataset
dataset.head(20)
# Out:
#                                             Sentences  \
# 0   tranche increased tonne tonne south korea adde...
# 1   showa denko export aluminium casting equipment...
# 2   note company ' full name gebrueder sulzer ag l...
# 3   romero said philippine end five year coconut p...
# 4   lme warehouse stock near two year low tonne fa...
# 5   many major nation yesterday intervened heavily...
# 6   transaction structured merger liberty duly for...
# 7   said ec failed follow consultation procedure l...
# 8   dollar fell low yen despite central bank inter...
# 9   george wimpey say benefit restructuring seen g...
# 10  ' dangerous go retaliatory route said lead ret...
# 11                                       indication u
# 12  five ship loaded raw sugar awaiting silvertown...
# 13  jeffrey leeds chemical bank convinced fed tigh...
# 14  prospect significant improvement unemployment ...
# 15  woodstock holding company mln dlr state bank w...
# 16  said every two half week american dy salmonell...
# 17      formed self contained part overall group said
# 18  trans lux connecticut concern lease teleprinte...
# 19  crushing would commence labasa penang mill jun...
#
#                                               unigram  \
# 0   [[tranche], [increased], [tonne], [tonne], [so...
# 1   [[showa], [denko], [export], [aluminium], [cas...
# 2   [[note], [company], ['], [full], [name], [gebr...
# 3   [[romero], [said], [philippine], [end], [five]...
# 4   [[lme], [warehouse], [stock], [near], [two], [...
# 5   [[many], [major], [nation], [yesterday], [inte...
# 6   [[transaction], [structured], [merger], [liber...
# 7   [[said], [ec], [failed], [follow], [consultati...
# 8   [[dollar], [fell], [low], [yen], [despite], [c...
# 9   [[george], [wimpey], [say], [benefit], [restru...
# 10  [['], [dangerous], [go], [retaliatory], [route...
# 11                                [[indication], [u]]
# 12  [[five], [ship], [loaded], [raw], [sugar], [aw...
# 13  [[jeffrey], [leeds], [chemical], [bank], [conv...
# 14  [[prospect], [significant], [improvement], [un...
# 15  [[woodstock], [holding], [company], [mln], [dl...
# 16  [[said], [every], [two], [half], [week], [amer...
# 17  [[formed], [self], [contained], [part], [overa...
# 18  [[trans], [lux], [connecticut], [concern], [le...
# 19  [[crushing], [would], [commence], [labasa], [p...
#
#                                                bigram
# 0   [[tranche, increased], [increased, tonne], [to...
# 1   [[showa, denko], [denko, export], [export, alu...
# 2   [[note, company], [company, '], [', full], [fu...
# 3   [[romero, said], [said, philippine], [philippi...
# 4   [[lme, warehouse], [warehouse, stock], [stock,...
# 5   [[many, major], [major, nation], [nation, yest...
# 6   [[transaction, structured], [structured, merge...
# 7   [[said, ec], [ec, failed], [failed, follow], [...
# 8   [[dollar, fell], [fell, low], [low, yen], [yen...
# 9   [[george, wimpey], [wimpey, say], [say, benefi...
# 10  [[', dangerous], [dangerous, go], [go, retalia...
# 11                                  [[indication, u]]
# 12  [[five, ship], [ship, loaded], [loaded, raw], ...
# 13  [[jeffrey, leeds], [leeds, chemical], [chemica...
# 14  [[prospect, significant], [significant, improv...
# 15  [[woodstock, holding], [holding, company], [co...
# 16  [[said, every], [every, two], [two, half], [ha...
# 17  [[formed, self], [self, contained], [contained...
# 18  [[trans, lux], [lux, connecticut], [connecticu...
# 19  [[crushing, would], [would, commence], [commen...

# %%
# sample sentence
dataset['Sentences'][0]
# Out:
# 'tranche increased tonne tonne south korea added possible destination'

# %%
# unigram of the sentence
dataset['unigram'][0]
# Out:
# [['tranche'],
#  ['increased'],
#  ['tonne'],
#  ['tonne'],
#  ['south'],
#  ['korea'],
#  ['added'],
#  ['possible'],
#  ['destination']]

# %%
# bigram of the sentence
dataset['bigram'][0]
# Out:
# [['tranche', 'increased'],
#  ['increased', 'tonne'],
#  ['tonne', 'tonne'],
#  ['tonne', 'south'],
#  ['south', 'korea'],
#  ['korea', 'added'],
#  ['added', 'possible'],
#  ['possible', 'destination']]

# %%
# trigram of the sentence
dataset['trigram'][0]
# Out:
# [['but', 'now', 'both'],
#  ['now', 'both', 'tranches'],
#  ['both', 'tranches', 'have'],
#  ['tranches', 'have', 'been'],
#  ['have', 'been', 'increased'],
#  ['been', 'increased', 'by'],
#  ['increased', 'by', 'tonnes'],
#  ['by', 'tonnes', 'to'],
#  ['tonnes', 'to', 'tonnes'],
#  ['to', 'tonnes', 'with'],
#  ['tonnes', 'with', 'south'],
#  ['with', 'south', 'korea'],
#  ['south', 'korea', 'added'],
#  ['korea', 'added', 'as'],
#  ['added', 'as', 'a'],
#  ['as', 'a', 'possible'],
#  ['a', 'possible', 'destination']]

# %% [markdown]
# ## 3. Building the N-gram Language Model

# %%
# for defining the N-gram model
from collections import Counter, defaultdict

# Create a placeholder for model
model = defaultdict(lambda: defaultdict(lambda: 0))

# Count frequency of co-occurance
for i in range(dataset.shape[0]):
    # for each trigram pair
    for w1, w2, w3 in create_trigram(dataset['Sentences'][i]):
        # count the occurance of word 3, given word 1 and word 2
        model[(w1, w2)][w3] += 1

# %%
# defined model
model
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {('tranche',
#               'increased'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tonne': 1}),
#              ('increased',
#               'tonne'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tonne': 1,
#                           'department': 1}),
#              ('tonne',
#               'tonne'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'south': 1,
#                           'year': 1,
#                           'previous': 1,
#                           'tin': 1,
#                           'higher': 1}),
#              ('tonne',
#               'south'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'korea': 1,
#                           'african': 2}),
#              ('south',
#               'korea'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'added': 1,
#                           'reagan': 1,
#                           'reliant': 1,
#                           'italy': 1,
#                           'corn': 1,
#                           "'": 10,
#                           'pressure': 1,
#                           'billion': 1,
#                           'u': 1,
#                           'trade': 1,
#                           'raise': 1,
#                           'raised': 1,
#                           'market': 1,
#                           'cut': 3,
#                           'spain': 1,
#                           'increase': 1,
#                           'increased': 1,
#                           'acceptable': 1,
#                           'taiwan': 1,
#                           'philippine': 1}),
#              ('korea',
#               'added'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'possible': 1}),
#              ('added',
#               'possible'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'destination': 1}),
#              ('showa',
#               'denko'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'export': 1,
#                           'ltd': 1,
#                           'withdrew': 1}),
#              ('denko',
#               'export'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'aluminium': 1}),
#              ('export',
#               'aluminium'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'casting': 1}),
#              ('aluminium',
#               'casting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'equipment': 1}),
#              ('casting',
#               'equipment'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lt': 1,
#                           'technology': 1}),
#              ('equipment',
#               'lt'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'showa': 1}),
#              ('lt',
#               'showa'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'denko': 1}),
#              ('denko',
#               'ltd'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'said': 1}),
#              ('ltd',
#               'said'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'exporting': 1,
#                           'would': 5,
#                           'report': 1,
#                           'received': 1,
#                           'jannock': 1,
#                           'board': 1,
#                           'sold': 1,
#                           'operating': 1,
#                           'raised': 2,
#                           'hourly': 2,
#                           'expects': 2,
#                           'acquire': 1,
#                           'proposed': 2,
#                           'exchanged': 1,
#                           'agreed': 3,
#                           'sttement': 1,
#                           'bought': 1,
#                           'lowered': 1,
#                           'toronto': 1,
#                           'geologist': 1,
#                           'cut': 1,
#                           'shareholder': 1,
#                           'statement': 1}),
#              ('said',
#               'exporting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'aluminium': 1}),
#              ('exporting',
#               'aluminium'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'billet': 1}),
#              ('aluminium',
#               'billet'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'casting': 1}),
#              ('billet',
#               'casting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'equipment': 1}),
#              ('equipment',
#               'technology'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'country': 1,
#                           'said': 1}),
#              ('technology',
#               'country'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'recently': 1}),
#              ('country',
#               'recently'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'begun': 1}),
#              ('recently',
#               'begun'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'aluminium': 1}),
#              ('begun',
#               'aluminium'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'smelting': 1}),
#              ('note',
#               'company'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {"'": 3,
#                           'went': 4,
#                           'converted': 1,
#                           'report': 1,
#                           'forecast': 1,
#                           'changed': 1,
#                           'subsidiary': 1,
#                           'said': 2,
#                           'initial': 1,
#                           'name': 1,
#                           'began': 2,
#                           'became': 2,
#                           'full': 1,
#                           'recently': 1}),
#              ('company',
#               "'"): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'full': 7,
#                           'done': 1,
#                           'stake': 1,
#                           'filing': 1,
#                           'recent': 1,
#                           'financial': 1,
#                           'tea': 1,
#                           'special': 1,
#                           'board': 3,
#                           'seven': 1,
#                           'stock': 6,
#                           'annual': 3,
#                           'situation': 1,
#                           'acquisition': 1,
#                           'april': 1,
#                           'gas': 1,
#                           'illegal': 1,
#                           'common': 3,
#                           'previously': 1,
#                           'holding': 1,
#                           'restricted': 1,
#                           'reach': 1,
#                           'fundamental': 1,
#                           'decision': 1,
#                           'fertilizer': 1,
#                           'result': 1,
#                           'judgement': 1,
#                           'existing': 1,
#                           'tonnage': 1,
#                           'director': 1,
#                           'revenue': 2,
#                           'proposed': 2,
#                           'price': 1,
#                           'exploration': 1,
#                           'ongoing': 1,
#                           'profit': 4,
#                           'outlook': 1,
#                           'product': 2,
#                           'net': 1,
#                           'retained': 1,
#                           'mln': 2,
#                           'operation': 1,
#                           'mine': 1,
#                           'acquistions': 1,
#                           'woman': 1,
#                           'billion': 1,
#                           'data': 1,
#                           'option': 1,
#                           'total': 3,
#                           'largest': 1,
#                           'proposal': 1,
#                           'management': 1,
#                           'three': 1,
#                           'life': 2,
#                           'statement': 1,
#                           'business': 1,
#                           'cleveland': 1,
#                           'authorized': 1,
#                           'first': 1}),
#              ("'",
#               'full'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'name': 6,
#                           'year': 1,
#                           'line': 1,
#                           'council': 1}),
#              ('full',
#               'name'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'gebrueder': 1,
#                           'norcros': 1,
#                           'royex': 1,
#                           'company': 6,
#                           'universal': 2,
#                           'montgomery': 1,
#                           'hanson': 1,
#                           'international': 2,
#                           'vieille': 1,
#                           'atlas': 1,
#                           'united': 1,
#                           'data': 1,
#                           'blue': 1,
#                           'burmah': 1,
#                           'volkswagen': 1,
#                           'standard': 1,
#                           'allegheny': 1,
#                           'burlington': 1,
#                           'morgan': 1,
#                           'scott': 1}),
#              ('name',
#               'gebrueder'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sulzer': 1}),
#              ('gebrueder',
#               'sulzer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ag': 1,
#                           'profit': 1}),
#              ('sulzer',
#               'ag'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lt': 1}),
#              ('ag',
#               'lt'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sulz': 1,
#                           'ling': 1,
#                           'vowg': 3}),
#              ('lt',
#               'sulz'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'z': 1}),
#              ('romero',
#               'said'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'philippine': 1,
#                           'interview': 1,
#                           'would': 2,
#                           'group': 1,
#                           'another': 1}),
#              ('said',
#               'philippine'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'end': 1}),
#              ('philippine',
#               'end'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'five': 1}),
#              ('end',
#               'five'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'year': 1}),
#              ('five',
#               'year'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'coconut': 1,
#                           'production': 1,
#                           'ecuador': 1,
#                           'colombian': 1,
#                           'average': 1,
#                           'instead': 1,
#                           'issuance': 1,
#                           'separatist': 1,
#                           'said': 1,
#                           'income': 1,
#                           'billion': 1,
#                           'meat': 1,
#                           'added': 1,
#                           'fixed': 1,
#                           'based': 1,
#                           'certain': 1,
#                           'development': 1,
#                           'subordinated': 1,
#                           'period': 1,
#                           'acquisition': 1,
#                           'pct': 1,
#                           'restructuring': 1}),
#              ('year',
#               'coconut'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'production': 1}),
#              ('coconut',
#               'production'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'cycle': 1,
#                           'major': 1}),
#              ('production',
#               'cycle'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'showed': 1}),
#              ('cycle',
#               'showed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'production': 1}),
#              ('showed',
#               'production'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tended': 1}),
#              ('production',
#               'tended'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'fall': 1}),
#              ('tended',
#               'fall'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'two': 1}),
#              ('fall',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'successive': 1,
#                           'billion': 2}),
#              ('two',
#               'successive'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'year': 1}),
#              ('successive',
#               'year'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'good': 1,
#                           'high': 1}),
#              ('year',
#               'good'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'harvest': 1}),
#              ('lme',
#               'warehouse'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'stock': 1}),
#              ('warehouse',
#               'stock'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'near': 1,
#                           'money': 1}),
#              ('stock',
#               'near'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'two': 1}),
#              ('near',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'year': 1}),
#              ('two',
#               'year'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'low': 1,
#                           'successful': 1,
#                           'could': 1,
#                           'contract': 2,
#                           'issuance': 1,
#                           'extension': 1,
#                           'ago': 4,
#                           'decline': 1,
#                           'develop': 1,
#                           'competitive': 1,
#                           'interim': 1,
#                           'commodity': 1,
#                           'sharp': 1,
#                           'imposition': 1,
#                           'rising': 1}),
#              ('year',
#               'low'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tonne': 1,
#                           'yen': 3,
#                           'dlrs': 1,
#                           'likely': 1,
#                           'oil': 1,
#                           'stg': 1}),
#              ('low',
#               'tonne'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'fallen': 1}),
#              ('tonne',
#               'fallen'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'steadily': 1}),
#              ('fallen',
#               'steadily'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'record': 1}),
#              ('steadily',
#               'record'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'high': 1}),
#              ('record',
#               'high'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tonne': 1,
#                           'yield': 1,
#                           'tin': 1}),
#              ('high',
#               'tonne'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'reached': 1}),
#              ('tonne',
#               'reached'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'february': 1}),
#              ('many',
#               'major'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'nation': 2}),
#              ('major',
#               'nation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'yesterday': 2}),
#              ('nation',
#               'yesterday'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'intervened': 2}),
#              ('yesterday',
#               'intervened'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'heavily': 2}),
#              ('intervened',
#               'heavily'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'aid': 2}),
#              ('heavily',
#               'aid'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'dlr': 2}),
#              ('aid',
#               'dlr'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'miyazawa': 2,
#                           'finance': 1}),
#              ('transaction',
#               'structured'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'merger': 1}),
#              ('structured',
#               'merger'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'liberty': 1,
#                           'holder': 1}),
#              ('merger',
#               'liberty'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'duly': 1}),
#              ('liberty',
#               'duly'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'formed': 1}),
#              ('duly',
#               'formed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'unit': 1}),
#              ('formed',
#               'unit'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'equimark': 1}),
#              ('unit',
#               'equimark'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'company': 1}),
#              ('equimark',
#               'company'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'said': 1}),
#              ('said',
#               'ec'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'failed': 1,
#                           'joined': 1,
#                           'standard': 1,
#                           'foreign': 1,
#                           'would': 1}),
#              ('ec',
#               'failed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'follow': 1}),
#              ('failed',
#               'follow'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'consultation': 1}),
#              ('follow',
#               'consultation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'procedure': 1}),
#              ('consultation',
#               'procedure'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'laid': 1,
#                           'said': 1}),
#              ('procedure',
#               'laid'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lome': 1}),
#              ('laid',
#               'lome'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'convention': 1}),
#              ('lome',
#               'convention'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'regulates': 1}),
#              ('convention',
#               'regulates'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'relation': 1}),
#              ('regulates',
#               'relation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'acp': 1}),
#              ('relation',
#               'acp'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'state': 1}),
#              ('acp',
#               'state'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'bloc': 1,
#                           'told': 1,
#                           'say': 1}),
#              ('state',
#               'bloc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'move': 1}),
#              ('bloc',
#               'move'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'could': 1}),
#              ('move',
#               'could'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'affect': 1,
#                           'done': 1}),
#              ('could',
#               'affect'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'trade': 1}),
#              ('affect',
#               'trade'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'two': 1}),
#              ('trade',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'side': 1}),
#              ('dollar',
#               'fell'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'low': 2,
#                           'year': 3,
#                           'yen': 3}),
#              ('fell',
#               'low'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'yen': 2}),
#              ('low',
#               'yen'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'despite': 2,
#                           'dollar': 2,
#                           'set': 2,
#                           'nervous': 1,
#                           'tokyo': 2,
#                           'new': 1,
#                           'friday': 1,
#                           'previous': 1,
#                           'heavy': 1,
#                           'enjoyed': 1}),
#              ('yen',
#               'despite'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'central': 1,
#                           'aggressive': 1,
#                           'massive': 1}),
#              ('despite',
#               'central'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'bank': 2}),
#              ('central',
#               'bank'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'intervention': 8,
#                           'bought': 4,
#                           'credit': 1,
#                           'governor': 9,
#                           'suffered': 1,
#                           'planning': 1,
#                           'kenya': 1,
#                           'finance': 1,
#                           'froze': 1,
#                           'purchase': 1,
#                           'encouraged': 1,
#                           'always': 1,
#                           "'": 7,
#                           'issued': 1,
#                           'added': 2,
#                           'might': 2,
#                           'sold': 1,
#                           'lowered': 2,
#                           'agree': 1,
#                           'special': 1,
#                           'actively': 2,
#                           'said': 10,
#                           'decision': 1,
#                           'spokesman': 2,
#                           'made': 1,
#                           'kept': 1,
#                           'aid': 1,
#                           'plan': 1,
#                           'bundesbank': 2,
#                           'council': 2,
#                           'sufficient': 1,
#                           'announced': 1,
#                           'money': 2,
#                           'cooperation': 1,
#                           'major': 1,
#                           'source': 4,
#                           'ecuador': 1,
#                           'rapidly': 1,
#                           'supported': 1,
#                           'last': 1,
#                           'poehl': 1,
#                           'move': 1,
#                           'pay': 1,
#                           'appear': 1,
#                           'placed': 1,
#                           'intention': 1,
#                           'warns': 1,
#                           'trading': 1,
#                           'president': 3,
#                           'quietly': 1,
#                           'head': 1,
#                           'figure': 1,
#                           'previously': 1,
#                           'also': 1,
#                           'saw': 1,
#                           'restrictive': 1,
#                           'see': 1,
#                           'defend': 1,
#                           'clamped': 1,
#                           'reach': 1,
#                           'easing': 1}),
#              ('bank',
#               'intervention'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'yen': 1,
#                           'long': 1,
#                           'interest': 1,
#                           'support': 1,
#                           'feel': 1,
#                           'near': 1,
#                           'open': 1}),
#              ('intervention',
#               'yen'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'dealer': 1}),
#              ('yen',
#               'dealer'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'said': 5}),
#              ('george',
#               'wimpey'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'say': 1,
#                           'plc': 2}),
#              ('wimpey',
#               'say'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'benefit': 1}),
#              ('say',
#               'benefit'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'restructuring': 1}),
#              ('benefit',
#               'restructuring'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'seen': 1,
#                           'chairman': 1}),
#              ('restructuring',
#               'seen'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'george': 1}),
#              ('seen',
#               'george'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'wimpey': 1}),
#              ('wimpey',
#               'plc'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lt': 2}),
#              ('plc',
#               'lt'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'wmpy': 2,
#                           'bwtr': 1,
#                           'ncro': 1,
#                           'lonl': 1,
#                           'rtzl': 2,
#                           'nwbl': 1,
#                           'dxns': 1,
#                           'burm': 2,
#                           'bti': 1,
#                           'lexl': 1,
#                           'sehl': 1,
#                           'snb': 1,
#                           'han': 1,
#                           'rot': 2,
#                           'dlar': 1,
#                           'bp': 3,
#                           'gecl': 1,
#                           'un': 2,
#                           'hnsn': 1,
#                           'brfd': 2,
#                           'rdld': 3,
#                           'stch': 1,
#                           'bcil': 1,
#                           'mgcr': 2,
#                           'reed': 2,
#                           'bpl': 1,
#                           'cawl': 2,
#                           'japanese': 1,
#                           'hldn': 1,
#                           'mepc': 1,
#                           'glyn': 1,
#                           'bpcl': 1,
#                           'kwik': 1,
#                           'hepc': 1}),
#              ('lt',
#               'wmpy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'l': 2}),
#              ('wmpy',
#               'l'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'said': 1}),
#              ('l',
#               'said'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'outlook': 1,
#                           'sharply': 1,
#                           'statement': 1,
#                           'acquired': 1,
#                           'agreed': 2,
#                           'prospect': 1,
#                           'christie': 1,
#                           'offer': 1,
#                           'bought': 1}),
#              ('said',
#               'outlook'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'looked': 1,
#                           'year': 1,
#                           'major': 1}),
#              ('outlook',
#               'looked'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'encouraging': 1}),
#              ('looked',
#               'encouraging'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'company': 1}),
#              ('encouraging',
#               'company'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'realised': 1}),
#              ('company',
#               'realised'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'continuing': 1}),
#              ('realised',
#               'continuing'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'benefit': 1}),
#              ('continuing',
#               'benefit'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'restructuring': 1}),
#              ("'",
#               'dangerous'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'go': 1}),
#              ('dangerous',
#               'go'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'retaliatory': 1}),
#              ('go',
#               'retaliatory'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'route': 1}),
#              ('retaliatory',
#               'route'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'said': 1}),
#              ('route',
#               'said'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lead': 1}),
#              ('said',
#               'lead'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'retaliation': 1}),
#              ('lead',
#               'retaliation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'restriction': 1}),
#              ('retaliation',
#               'restriction'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'trade': 1}),
#              ('five',
#               'ship'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'loaded': 1}),
#              ('ship',
#               'loaded'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'raw': 1}),
#              ('loaded',
#               'raw'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'sugar': 1}),
#              ('raw',
#               'sugar'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'awaiting': 1,
#                           'reported': 1,
#                           'various': 1,
#                           'jetty': 1,
#                           'sold': 1,
#                           'unloaded': 1}),
#              ('sugar',
#               'awaiting'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'silvertown': 1}),
#              ('awaiting',
#               'silvertown'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'discharged': 1}),
#              ('silvertown',
#               'discharged'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tate': 1}),
#              ('discharged',
#               'tate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lyle': 1}),
#              ('tate',
#               'lyle'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'added': 1,
#                           'said': 1,
#                           'london': 1,
#                           'plc': 1}),
#              ('jeffrey',
#               'leeds'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'chemical': 1}),
#              ('leeds',
#               'chemical'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'bank': 1}),
#              ('chemical',
#               'bank'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'convinced': 1}),
#              ('bank',
#               'convinced'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'fed': 1}),
#              ('convinced',
#               'fed'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'tightening': 1}),
#              ('fed',
#               'tightening'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'policy': 2,
#                           'could': 1}),
#              ('prospect',
#               'significant'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'improvement': 1}),
#              ('significant',
#               'improvement'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'unemployment': 1,
#                           'external': 1}),
#              ('improvement',
#               'unemployment'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'situation': 1}),
#              ('unemployment',
#               'situation'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'next': 1}),
#              ('situation',
#               'next'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'month': 1}),
#              ('next',
#               'month'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'average': 1,
#                           'map': 1,
#                           "'": 1,
#                           'company': 1,
#                           'tetsuo': 1,
#                           'plant': 1,
#                           'gold': 1,
#                           'looking': 1,
#                           'period': 1,
#                           'ecuador': 1}),
#              ('month',
#               'average'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rate': 1}),
#              ('average',
#               'rate'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'expected': 1,
#                           'inflation': 1,
#                           'pct': 1,
#                           'rise': 2,
#                           'convertible': 1}),
#              ('rate',
#               'expected'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'stabilize': 1,
#                           'edge': 1,
#                           'strengthen': 1}),
#              ('expected',
#               'stabilize'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pct': 1,
#                           'around': 1}),
#              ('stabilize',
#               'pct'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'similar': 1}),
#              ('pct',
#               'similar'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'last': 1,
#                           'increase': 2,
#                           'share': 1}),
#              ('similar',
#               'last'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'year': 2}),
#              ('woodstock',
#               'holding'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'company': 1}),
#              ('holding',
#               'company'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'mln': 1,
#                           'equal': 1,
#                           'owns': 1,
#                           'also': 2,
#                           'parent': 1,
#                           'said': 1,
#                           'boston': 1,
#                           'texaco': 1,
#                           'montedison': 1,
#                           'society': 2}),
#              ('company',
#               'mln'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'dlr': 1,
#                           'dlrs': 2,
#                           'stg': 2,
#                           'v': 2,
#                           'share': 2}),
#              ('mln',
#               'dlr'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'state': 1,
#                           'fee': 2,
#                           'principle': 1,
#                           'margin': 1,
#                           'restructuring': 1,
#                           'operating': 1,
#                           'tally': 1,
#                           'loan': 2,
#                           'purchase': 1,
#                           'gain': 3,
#                           'reduction': 1,
#                           'contract': 1,
#                           'merger': 1,
#                           'loss': 3,
#                           'tax': 2,
#                           'modernization': 1,
#                           'charge': 4,
#                           'takeover': 1,
#                           'writedown': 1,
#                           'deficit': 4,
#                           'net': 1,
#                           'award': 1,
#                           'surplus': 6,
#                           'bid': 1,
#                           'line': 1,
#                           'ec': 1,
#                           'private': 1,
#                           'receivable': 1,
#                           'decline': 1,
#                           'share': 1,
#                           'alumina': 1,
#                           'special': 1,
#                           'one': 1,
#                           'revised': 1,
#                           'current': 2,
#                           'credit': 1,
#                           'three': 1,
#                           'asset': 1}),
#              ('dlr',
#               'state'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'bank': 1}),
#              ('state',
#               'bank'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'woodstock': 1,
#                           'kreditanstalt': 2}),
#              ('said',
#               'every'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'two': 1}),
#              ('every',
#               'two'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'half': 1}),
#              ('two',
#               'half'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'week': 1}),
#              ('half',
#               'week'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'american': 1}),
#              ('week',
#               'american'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'dy': 1}),
#              ('american',
#               'dy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'salmonellosis': 1}),
#              ('dy',
#               'salmonellosis'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'complication': 1}),
#              ('salmonellosis',
#               'complication'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'arising': 1}),
#              ('complication',
#               'arising'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'incidence': 1}),
#              ('arising',
#               'incidence'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'poisoning': 1}),
#              ('incidence',
#               'poisoning'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'poultry': 1}),
#              ('poisoning',
#               'poultry'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'increased': 1}),
#              ('poultry',
#               'increased'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'steadily': 1}),
#              ('increased',
#               'steadily'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'past': 1}),
#              ('steadily',
#               'past'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'several': 1}),
#              ('past',
#               'several'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'year': 1,
#                           'week': 2}),
#              ('formed',
#               'self'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'contained': 1}),
#              ('self',
#               'contained'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'part': 1}),
#              ('contained',
#               'part'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'overall': 1}),
#              ('part',
#               'overall'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'group': 1,
#                           'budget': 1}),
#              ('overall',
#               'group'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'said': 1}),
#              ('trans',
#               'lux'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'connecticut': 1,
#                           'common': 1,
#                           'shareholder': 1,
#                           'board': 1}),
#              ('lux',
#               'connecticut'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'concern': 1}),
#              ('connecticut',
#               'concern'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lease': 1}),
#              ('concern',
#               'lease'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'teleprinter': 1}),
#              ('lease',
#               'teleprinter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'display': 1}),
#              ('teleprinter',
#               'display'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'unit': 1}),
#              ('display',
#               'unit'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'brokerage': 1}),
#              ('unit',
#               'brokerage'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'office': 1}),
#              ('brokerage',
#               'office'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'airport': 1}),
#              ('office',
#               'airport'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'public': 1}),
#              ('airport',
#               'public'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'place': 1}),
#              ('crushing',
#               'would'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'commence': 1}),
#              ('would',
#               'commence'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'labasa': 1}),
#              ('commence',
#               'labasa'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'penang': 1}),
#              ('labasa',
#               'penang'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'mill': 1}),
#              ('penang',
#               'mill'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'june': 1}),
#              ('mill',
#               'june'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lautoka': 1,
#                           'said': 1}),
#              ('june',
#               'lautoka'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'rarawai': 1}),
#              ('lautoka',
#               'rarawai'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'mill': 1}),
#              ('rarawai',
#               'mill'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'june': 1}),
#              ('brooklyn',
#               'union'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'fourth': 1,
#                           'relied': 1,
#                           'lt': 1,
#                           'gas': 2,
#                           'continue': 1,
#                           'official': 1,
#                           'paid': 1,
#                           'steve': 1,
#                           "'": 1,
#                           'exploration': 1}),
#              ('union',
#               'fourth'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'largest': 1}),
#              ('fourth',
#               'largest'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'gas': 1}),
#              ('largest',
#               'gas'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'utility': 1}),
#              ('gas',
#               'utility'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'united': 1,
#                           'see': 1,
#                           'along': 1}),
#              ('utility',
#               'united'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'state': 1}),
#              ('united',
#               'state'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'purchased': 1,
#                           'made': 2,
#                           'negotiation': 1,
#                           'imposes': 2,
#                           'ill': 1,
#                           'island': 2,
#                           'brand': 1,
#                           'france': 1,
#                           'step': 1,
#                           'criticising': 1,
#                           'far': 1,
#                           'help': 2,
#                           'beef': 1,
#                           'six': 1,
#                           'well': 1,
#                           'included': 1,
#                           'mexico': 1,
#                           'market': 1,
#                           'lead': 1,
#                           'influence': 1,
#                           'took': 1,
#                           'ally': 1,
#                           'stop': 1,
#                           'european': 1,
#                           'traditional': 1,
#                           'agreed': 2,
#                           'cent': 1,
#                           'open': 2,
#                           'elsewhere': 1,
#                           'could': 1,
#                           'canada': 2,
#                           'finance': 2,
#                           'abroad': 1,
#                           'japan': 3,
#                           'would': 3,
#                           'face': 1,
#                           'asked': 1,
#                           'japanese': 1,
#                           'maintained': 1,
#                           'despite': 1,
#                           "'": 1,
#                           'usda': 1,
#                           'year': 1,
#                           'requires': 1,
#                           'consider': 1,
#                           'said': 2,
#                           'drop': 1,
#                           'may': 1,
#                           'enjoys': 1,
#                           'major': 1,
#                           'citizen': 1,
#                           'recent': 1,
#                           'long': 1,
#                           'really': 1,
#                           'want': 1,
#                           'seriously': 1,
#                           'take': 1,
#                           'house': 1,
#                           'revenue': 1,
#                           'successfully': 1,
#                           'decided': 1,
#                           'able': 1,
#                           'little': 1}),
#              ('state',
#               'purchased'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'pct': 1}),
#              ('purchased',
#               'pct'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'supply': 1,
#                           'parcel': 1,
#                           'interest': 1}),
#              ('pct',
#               'supply'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'spot': 1}),
#              ('supply',
#               'spot'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'non': 1}),
#              ('spot',
#               'non'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'contract': 1}),
#              ('non',
#               'contract'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'market': 1}),
#              ('contract',
#               'market'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'proportion': 1}),
#              ('market',
#               'proportion'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'spot': 1}),
#              ('proportion',
#               'spot'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'supply': 1}),
#              ('spot',
#               'supply'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'estimated': 1,
#                           'high': 1}),
#              ('supply',
#               'estimated'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'much': 1,
#                           'record': 1}),
#              ('estimated',
#               'much'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'higher': 1}),
#              ('much',
# ...
#              ('plan',
#               'put'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 1}),
#              ('put',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'flag': 1,
#                           'strong': 1,
#                           'k': 1}),
#              ('u',
#               'flag'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'kuwaiti': 1,
#                           'tanker': 1,
#                           'effectively': 2}),
#              ('flag',
#               'kuwaiti'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'ship': 1}),
#              ('kuwaiti',
#               'ship'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'charged': 1,
#                           'thus': 1,
#                           'sailed': 1}),
#              ('ship',
#               'charged'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'policy': 1}),
#              ('charged',
#               'policy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'could': 2}),
#              ('policy',
#               'could'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'lead': 2,
#                           'make': 1}),
#              ('could',
#               'lead'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'u': 1,
#                           'job': 1,
#                           'quick': 1,
#                           'impose': 1,
#                           'attractive': 1,
#                           'lower': 1,
#                           'offer': 1,
#                           'manufacturer': 1,
#                           'war': 1,
#                           'united': 1,
#                           'new': 1,
#                           'foreign': 1,
#                           'recession': 1}),
#              ('lead',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'iran': 1}),
#              ('u',
#               'iran'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'iraq': 1}),
#              ('iran',
#               'iraq'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'war': 2,
#                           'policy': 1,
#                           'high': 1,
#                           'soviet': 1}),
#              ('told',
#               'al'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'riyadh': 1}),
#              ('al',
#               'riyadh'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'newspaper': 1}),
#              ('riyadh',
#               'newspaper'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'saudi': 1}),
#              ('newspaper',
#               'saudi'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'arabia': 1}),
#              ('saudi',
#               'arabia'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'follows': 1,
#                           'usda': 3,
#                           'export': 1,
#                           "'": 5,
#                           'seeking': 1,
#                           'market': 1,
#                           'agree': 1,
#                           'buy': 1,
#                           'bought': 2,
#                           'delivery': 1,
#                           'architect': 2,
#                           'increased': 1,
#                           'opposes': 1,
#                           'kuwait': 1,
#                           'among': 1,
#                           'want': 1,
#                           'hope': 1}),
#              ('arabia',
#               'follows'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'balanced': 1}),
#              ('follows',
#               'balanced'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'petroleum': 1}),
#              ('balanced',
#               'petroleum'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'policy': 1}),
#              ('department',
#               'said'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'first': 1,
#                           'branding': 1,
#                           'since': 1,
#                           'april': 1,
#                           'action': 1,
#                           'bonus': 2,
#                           'figure': 1,
#                           'approved': 1,
#                           'iraq': 1,
#                           'fall': 1,
#                           'would': 1,
#                           'insurance': 1,
#                           'possible': 1,
#                           'reached': 1,
#                           'provision': 1,
#                           'private': 1,
#                           'year': 1,
#                           'thailand': 1}),
#              ('said',
#               'first'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'quarter': 13,
#                           'several': 1,
#                           'complete': 1,
#                           'half': 1,
#                           'tuskaloosa': 1,
#                           'two': 1}),
#              ('first',
#               'quarter'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'export': 2,
#                           'said': 2,
#                           'due': 4,
#                           'brand': 1,
#                           'year': 9,
#                           'net': 16,
#                           'fourth': 1,
#                           'middle': 1,
#                           'mln': 5,
#                           'earnings': 16,
#                           'production': 2,
#                           'loss': 9,
#                           'downturn': 1,
#                           'result': 7,
#                           'compared': 3,
#                           'import': 1,
#                           'profit': 6,
#                           'record': 1,
#                           'operating': 5,
#                           'adversely': 1,
#                           'last': 2,
#                           'deficit': 2,
#                           'ending': 1,
#                           'eight': 1,
#                           'unemployment': 1,
#                           'rate': 1,
#                           'includes': 1,
#                           'better': 1,
#                           'company': 1,
#                           'rising': 2,
#                           'cocoa': 1,
#                           'shr': 2,
#                           'allowed': 1,
#                           'sale': 2,
#                           'could': 1,
#                           'thailand': 1,
#                           'billion': 3,
#                           'revenue': 1,
#                           'soviet': 1,
#                           'met': 1,
#                           'rowe': 1,
#                           'consultation': 1,
#                           'outlook': 1,
#                           'ended': 2,
#                           'shipment': 1,
#                           'include': 1,
#                           'end': 1,
#                           'benefitted': 1,
#                           'substantially': 1,
#                           'west': 2,
#                           'widened': 1,
#                           'china': 1,
#                           'period': 1,
#                           'higher': 1,
#                           'pct': 1,
#                           'one': 1,
#                           'mainly': 1,
#                           'expected': 1,
#                           'growth': 1,
#                           'largely': 1,
#                           'bank': 1,
#                           'tonne': 1,
#                           'special': 1,
#                           'fell': 1}),
#              ('quarter',
#               'export'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'expanded': 1,
#                           'hong': 1}),
#              ('export',
#               'expanded'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'billion': 1,
#                           'kelly': 1}),
#              ('expanded',
#               'billion'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'baht': 1}),
#              ('billion',
#               'baht'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'billion': 2,
#                           'first': 1}),
#              ('deputy',
#               'u'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'trade': 3}),
#              ('u',
#               'trade'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'representative': 10,
#                           'deficit': 11,
#                           'official': 1,
#                           'gap': 3,
#                           'bill': 2,
#                           'data': 4,
#                           'panel': 2,
#                           'sanction': 1,
#                           'shortfall': 1,
#                           'improve': 1}),
#              ('trade',
#               'representative'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'michael': 3,
#                           'clayton': 5,
#                           "'": 2}),
#              ('representative',
#               'michael'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'smith': 3}),
#              ('michael',
#               'smith'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'makoto': 1,
#                           'aimed': 1,
#                           'secretary': 1}),
#              ('smith',
#               'makoto'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'kuroda': 1}),
#              ('makoto',
#               'kuroda'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'japan': 1,
#                           'vice': 1}),
#              ('kuroda',
#               'japan'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {"'": 1}),
#              ('japan',
#               "'"): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'deputy': 1,
#                           'top': 3,
#                           'current': 1,
#                           'electric': 1,
#                           'trade': 3,
#                           'little': 1,
#                           'economy': 3,
#                           'finance': 1,
#                           'edible': 1,
#                           'ruling': 4,
#                           'failure': 5,
#                           'central': 1,
#                           'semiconductor': 1,
#                           'restrictive': 1,
#                           'protected': 1,
#                           'private': 1,
#                           'liberal': 2,
#                           'ldp': 2,
#                           'bow': 1,
#                           'three': 1,
#                           'move': 2,
#                           'desire': 1,
#                           'crude': 1,
#                           'market': 1,
#                           'domestic': 1,
#                           'car': 1,
#                           'gross': 1,
#                           'international': 1,
#                           'lucrative': 1,
#                           'constitution': 1,
#                           'larger': 1,
#                           'ministry': 1,
#                           'profitable': 1,
#                           'adherence': 1,
#                           'promise': 1,
#                           'june': 1,
#                           'custom': 1,
#                           'agriculture': 1,
#                           'cabinet': 1,
#                           'alleged': 2,
#                           'flexible': 1,
#                           'agricultural': 1,
#                           'gnp': 1}),
#              ("'",
#               'deputy'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'minister': 1}),
#              ('deputy',
#               'minister'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'international': 1}),
#              ('minister',
#               'international'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'trade': 3}),
#              ('international',
#               'trade'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'industry': 8,
#                           'commission': 2,
#                           'upheld': 1,
#                           'said': 1}),
#              ('trade',
#               'industry'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'miti': 5,
#                           'ministry': 1,
#                           'secretary': 2,
#                           'expected': 1,
#                           'hajime': 1,
#                           'said': 1,
#                           'figure': 1}),
#              ('industry',
#               'miti'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'due': 1,
#                           'hold': 1,
#                           'said': 1,
#                           'recommended': 1}),
#              ('miti',
#               'due'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'meet': 1}),
#              ('due',
#               'meet'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'washington': 1,
#                           'prime': 1}),
#              ('meet',
#               'washington'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'week': 1}),
#              ('washington',
#               'week'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'effort': 1}),
#              ('week',
#               'effort'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'end': 1}),
#              ('effort',
#               'end'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'dispute': 1}),
#              ('legislation',
#               'supported'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'congress': 1}),
#              ('supported',
#               'congress'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {"'": 1}),
#              ('congress',
#               "'"): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'democratic': 1}),
#              ("'",
#               'democratic'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'republican': 1}),
#              ('democratic',
#               'republican'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'leadership': 1,
#                           'congressional': 1}),
#              ('republican',
#               'leadership'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'well': 1}),
#              ('leadership',
#               'well'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'administration': 1}),
#              ('well',
#               'administration'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'required': 1}),
#              ('administration',
#               'required'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'defense': 1}),
#              ('required',
#               'defense'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'secretary': 1}),
#              ('defense',
#               'secretary'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'caspar': 1}),
#              ('secretary',
#               'caspar'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'weinberger': 1}),
#              ('caspar',
#               'weinberger'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'provide': 1}),
#              ('weinberger',
#               'provide'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'report': 1}),
#              ('provide',
#               'report'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'congress': 1}),
#              ('report',
#               'congress'): defaultdict(<function __main__.<lambda>.<locals>.<lambda>()>, {'within': 1,
#                           'required': 1}),
#              ...})

# %% [markdown]
# ## 4. Predicting the next word using N-gram Language Model

# %%
# predict the next word
dict(model["by", "an"])
# Out:
# {}

# %%
# another example
dict(model["oil", "supply"])
# Out:
# {'pct': 1,
#  'line': 1,
#  'group': 1,
#  'bi': 1,
#  'demand': 1,
#  'jeapordy': 1,
#  'total': 1,
#  'key': 1}

# %%
# another example
dict(model["increasing", "the"])
# Out:
# {}

# %%
# another example
dict(model["a", "step"])
# Out:
# {}

# %% [markdown]
# ### Probabilistic Output

# %%
# creating the unigram list
unigram_dict = {}
for i in tqdm(range(dataset.shape[0])):
    # add word-count pair to the dictionary
    for word in dataset['unigram'][i]:
        # check if the word is already in dictionary
        if word[0] in unigram_dict:
            # increment count of word by 1
            unigram_dict[word[0]] = unigram_dict[word[0]] + 1
        else:
            # add the word to dictionary with count 1
            unigram_dict[word[0]] = 1
# Out:
# 100%|██████████| 8000/8000 [00:00<00:00, 46338.86it/s]

# %%
# unigram list
unigram_dict
# Out:
# {'but': 524,
#  'now': 140,
#  'both': 70,
#  'tranches': 2,
#  'have': 443,
#  'been': 306,
#  'increased': 59,
#  'by': 1110,
#  'tonnes': 443,
#  'to': 5099,
#  'with': 913,
#  'south': 100,
#  'korea': 33,
#  'added': 188,
#  'as': 707,
#  'a': 3561,
#  'possible': 60,
#  'destination': 6,
#  'showa': 5,
#  'denko': 3,
#  'exports': 222,
#  'aluminium': 19,
#  'casting': 2,
#  'equipment': 34,
#  'lt': 1200,
#  'ltd': 212,
#  'said': 3701,
#  'it': 1577,
#  'is': 1132,
#  'exporting': 9,
#  'billet': 1,
#  'and': 3634,
#  'technology': 33,
#  'countries': 114,
#  'that': 1103,
#  'recently': 35,
#  'begun': 6,
#  'smelting': 5,
#  'note': 209,
#  'company': 681,
#  "'": 1683,
#  's': 2261,
#  'full': 69,
#  'name': 44,
#  'gebrueder': 2,
#  'sulzer': 2,
#  'ag': 12,
#  'sulz': 1,
#  'z': 9,
#  'romero': 8,
#  'the': 10053,
#  'philippines': 17,
#  'was': 919,
#  'at': 1063,
#  'end': 224,
#  'of': 5360,
#  'five': 208,
#  'year': 990,
#  'coconut': 15,
#  'production': 227,
#  'cycle': 2,
#  'which': 521,
#  'showed': 43,
#  'tended': 2,
#  'fall': 88,
#  'after': 299,
#  'two': 368,
#  'successive': 3,
#  'years': 123,
#  'good': 54,
#  'harvests': 4,
#  'lme': 18,
#  'warehouse': 7,
#  'stocks': 133,
#  'are': 492,
#  'near': 38,
#  'low': 61,
#  'having': 15,
#  'fallen': 11,
#  'steadily': 4,
#  'from': 1119,
#  'record': 150,
#  'high': 121,
#  'reached': 46,
#  'in': 4115,
#  'february': 150,
#  'many': 43,
#  'major': 164,
#  'nations': 58,
#  'yesterday': 133,
#  'intervened': 8,
#  'heavily': 9,
#  'aid': 27,
#  'dlr': 188,
#  'miyazawa': 26,
#  'transaction': 55,
#  'structured': 3,
#  'merger': 92,
#  'liberty': 14,
#  'duly': 1,
#  'formed': 24,
#  'unit': 135,
#  'equimark': 5,
#  'they': 414,
#  'ec': 136,
#  'failed': 15,
#  'follow': 10,
#  'consultation': 5,
#  'procedures': 16,
#  'laid': 3,
#  'down': 110,
#  'lome': 1,
#  'convention': 1,
#  'regulates': 2,
#  'relations': 9,
#  'between': 144,
#  'acp': 8,
#  'states': 118,
#  'bloc': 5,
#  'for': 2062,
#  'moves': 26,
#  'could': 234,
#  'affect': 17,
#  'trade': 436,
#  'sides': 9,
#  'dollar': 285,
#  'fell': 98,
#  'yen': 155,
#  'despite': 60,
#  'central': 152,
#  'bank': 500,
#  'intervention': 62,
#  'dealers': 110,
#  'george': 8,
#  'wimpey': 4,
#  'says': 117,
#  'benefits': 18,
#  'restructuring': 40,
#  'seen': 56,
#  'plc': 85,
#  'wmpy': 2,
#  'l': 57,
#  'outlook': 20,
#  'looked': 4,
#  'encouraging': 4,
#  'realised': 2,
#  'continuing': 45,
#  'very': 52,
#  'dangerous': 6,
#  'go': 32,
#  'retaliatory': 4,
#  'route': 4,
#  'he': 771,
#  'because': 172,
#  'leads': 5,
#  'more': 291,
#  'retaliation': 17,
#  'restrictions': 20,
#  'an': 680,
#  'indication': 6,
#  'u': 865,
#  'other': 261,
#  'ships': 31,
#  'loaded': 2,
#  'raw': 19,
#  'sugar': 98,
#  'awaiting': 7,
#  'silvertown': 2,
#  'be': 929,
#  'discharged': 2,
#  'tate': 5,
#  'lyle': 4,
#  'jeffrey': 3,
#  'leeds': 2,
#  'chemical': 50,
#  'had': 408,
#  'not': 645,
#  'convinced': 5,
#  'fed': 133,
#  'tightening': 11,
#  'policy': 118,
#  'there': 174,
#  'no': 232,
#  'prospect': 2,
#  'any': 110,
#  'significant': 31,
#  'improvement': 26,
#  'unemployment': 29,
#  'situation': 23,
#  'over': 190,
#  'next': 132,
#  'months': 131,
#  'average': 125,
#  'rate': 316,
#  'expected': 228,
#  'stabilize': 15,
#  'pct': 1509,
#  'similar': 32,
#  'last': 516,
#  'woodstock': 5,
#  'holding': 43,
#  'mln': 2521,
#  'state': 89,
#  'she': 27,
#  'every': 12,
#  'half': 88,
#  'weeks': 58,
#  'american': 107,
#  'dies': 3,
#  'salmonellosis': 2,
#  'or': 436,
#  'complications': 1,
#  'arising': 2,
#  'incidence': 2,
#  'poisoning': 3,
#  'poultry': 21,
#  'has': 737,
#  'past': 49,
#  'several': 63,
#  'self': 5,
#  'contained': 13,
#  'part': 71,
#  'overall': 30,
#  'group': 279,
#  'trans': 5,
#  'lux': 4,
#  'connecticut': 3,
#  'concern': 31,
#  'leases': 3,
#  'teleprinters': 1,
#  'display': 3,
#  'units': 40,
#  'brokerage': 9,
#  'offices': 7,
#  'airports': 1,
#  'public': 61,
#  'places': 3,
#  'crushing': 2,
#  'would': 747,
#  'commence': 3,
#  'labasa': 1,
#  'penang': 1,
#  'mills': 15,
#  'on': 1310,
#  'june': 197,
#  'lautoka': 2,
#  'rarawai': 1,
#  'brooklyn': 11,
#  'union': 84,
#  'fourth': 35,
#  'largest': 64,
#  'gas': 132,
#  'utility': 6,
#  'united': 136,
#  'purchased': 20,
#  'its': 1093,
#  'supplies': 49,
#  'spot': 33,
#  'non': 83,
#  'contract': 62,
#  'market': 395,
#  'proportion': 2,
#  'estimated': 80,
#  'much': 70,
#  'higher': 134,
#  'analysts': 142,
#  'while': 133,
#  'roth': 3,
#  'still': 95,
#  'interested': 15,
#  'acquiring': 18,
#  'turco': 2,
#  'atcor': 7,
#  'reviewing': 5,
#  'options': 20,
#  'potential': 22,
#  'buyers': 28,
#  'who': 76,
#  'expressed': 15,
#  'interest': 203,
#  'consumer': 75,
#  'products': 157,
#  'businesses': 38,
#  'we': 210,
#  'represent': 7,
#  'first': 371,
#  'victim': 1,
#  'move': 79,
#  'price': 322,
#  'natural': 43,
#  'resources': 34,
#  'according': 41,
#  'system': 78,
#  'zimmerman': 9,
#  'mobil': 14,
#  'mob': 5,
#  'north': 34,
#  'sea': 7,
#  'find': 17,
#  'corp': 500,
#  'wildcat': 1,
#  'well': 68,
#  'block': 14,
#  'british': 61,
#  'flowed': 2,
#  'cubic': 18,
#  'feet': 18,
#  'per': 274,
#  'day': 106,
#  'depths': 1,
#  'asset': 14,
#  'uam': 1,
#  'completes': 23,
#  'acquisition': 160,
#  'management': 102,
#  'completed': 50,
#  'rice': 50,
#  'hall': 4,
#  'james': 28,
#  'associates': 37,
#  'san': 26,
#  'diego': 4,
#  'undisclosed': 34,
#  'terms': 82,
#  'includes': 102,
#  'most': 82,
#  'lazere': 3,
#  'loan': 95,
#  'portfolio': 3,
#  'assets': 126,
#  'including': 78,
#  'miami': 4,
#  'office': 38,
#  'finland': 6,
#  'neste': 3,
#  'oy': 3,
#  'whose': 14,
#  'turnover': 27,
#  'billion': 856,
#  'dlrs': 1704,
#  'extensive': 4,
#  'experience': 7,
#  'mtbe': 6,
#  'arrangements': 10,
#  'financing': 47,
#  'yet': 43,
#  'made': 139,
#  'can': 98,
#  'assurance': 6,
#  'will': 791,
#  'received': 56,
#  'hmo': 2,
#  'asked': 58,
#  'why': 14,
#  'only': 146,
#  'japan': 344,
#  'committed': 8,
#  'fresh': 18,
#  'measures': 54,
#  'statement': 134,
#  'exceptional': 7,
#  'among': 31,
#  'seven': 115,
#  'appreciated': 2,
#  'against': 217,
#  'currencies': 45,
#  'largely': 13,
#  'stable': 28,
#  'initial': 28,
#  'distribution': 25,
#  'take': 109,
#  'form': 24,
#  'stock': 322,
#  'dividend': 108,
#  'cumulative': 23,
#  'redeemable': 5,
#  'retractable': 2,
#  'class': 23,
#  'series': 39,
#  'preferred': 61,
#  'shares': 410,
#  'entitling': 2,
#  'holders': 21,
#  'monthly': 30,
#  'floating': 8,
#  'dividends': 15,
#  'prime': 62,
#  'share': 398,
#  'retraction': 1,
#  'aristech': 3,
#  'ars': 1,
#  'st': 223,
#  'qtr': 373,
#  'shr': 500,
#  'estimate': 27,
#  'right': 30,
#  'chairman': 108,
#  'chief': 33,
#  'executive': 40,
#  'officer': 19,
#  'thomas': 4,
#  'marshall': 9,
#  'estimates': 44,
#  'fiscal': 68,
#  'earnings': 145,
#  'about': 427,
#  'hint': 1,
#  'what': 61,
#  'announcement': 43,
#  'might': 49,
#  'may': 435,
#  'buy': 128,
#  'wheat': 146,
#  'valued': 11,
#  'april': 376,
#  'august': 31,
#  'ship': 14,
#  'ports': 15,
#  'september': 39,
#  'department': 148,
#  'magellan': 7,
#  'did': 93,
#  'disclose': 12,
#  'agreement': 201,
#  'fees': 13,
#  'trust': 47,
#  'banking': 41,
#  'services': 59,
#  'rose': 191,
#  'earlier': 135,
#  'adams': 4,
#  'express': 6,
#  'co': 297,
#  'adx': 1,
#  'march': 246,
#  'vs': 1829,
#  'shrs': 134,
#  'out': 119,
#  'lastest': 1,
#  'capital': 86,
#  'gain': 80,
#  'distributions': 3,
#  'cts': 1000,
#  'december': 74,
#  'china': 91,
#  'resumes': 2,
#  'ussr': 17,
#  'repairs': 5,
#  'gap': 8,
#  'resumed': 4,
#  'soviet': 40,
#  'break': 14,
#  'caused': 32,
#  'ideological': 1,
#  'split': 61,
#  'seasonally': 28,
#  'adjusted': 74,
#  'index': 39,
#  'input': 4,
#  'prices': 309,
#  'rise': 195,
#  'rash': 1,
#  'advertising': 5,
#  'solicit': 3,
#  'new': 396,
#  'business': 127,
#  'helped': 16,
#  'homebuyers': 1,
#  'become': 36,
#  'even': 39,
#  'choosier': 1,
#  'loans': 99,
#  'lenders': 6,
#  'concede': 1,
#  'being': 79,
#  'forced': 13,
#  'undercut': 2,
#  'each': 95,
#  'totally': 3,
#  'unadjusted': 12,
#  'figures': 98,
#  'show': 51,
#  'deficit': 180,
#  'revised': 38,
#  'compared': 131,
#  'statistics': 34,
#  'producer': 45,
#  'heavy': 33,
#  'heating': 13,
#  'oil': 463,
#  'were': 493,
#  'liquefied': 3,
#  'coffee': 59,
#  'cheaper': 6,
#  'xebec': 6,
#  'also': 329,
#  'expects': 86,
#  'revenues': 58,
#  'total': 233,
#  'ncr': 9,
#  'say': 80,
#  'achieving': 2,
#  'recuperation': 2,
#  'credit': 117,
#  'cannot': 22,
#  'done': 19,
#  'overnight': 16,
#  'azpurua': 10,
#  'television': 21,
#  'interview': 18,
#  'commonwealth': 13,
#  'cuts': 69,
#  'australia': 47,
#  'lower': 127,
#  'lending': 14,
#  'effective': 71,
#  'progress': 17,
#  'all': 204,
#  'main': 34,
#  'sectors': 17,
#  'except': 14,
#  'goods': 56,
#  'where': 52,
#  'remain': 48,
#  'present': 31,
#  'level': 77,
#  'report': 169,
#  'fluor': 3,
#  'applied': 10,
#  'engineering': 6,
#  'construct': 2,
#  'modular': 1,
#  'sections': 3,
#  'deliver': 5,
#  'them': 47,
#  'ge': 6,
#  'waterford': 1,
#  'n': 68,
#  'y': 16,
#  'silicone': 1,
#  'division': 47,
#  'plant': 55,
#  'some': 217,
#  'merchants': 10,
#  'fear': 6,
#  'large': 59,
#  'tonnage': 7,
#  'delivered': 8,
#  'futures': 51,
#  'month': 202,
#  'possibly': 16,
#  'disrupt': 1,
#  'physical': 8,
#  'franc': 19,
#  'carries': 6,
#  'warrants': 20,
#  'today': 225,
#  'itc': 16,
#  'ruling': 26,
#  'consistent': 15,
#  'commerce': 34,
#  'final': 40,
#  'activates': 1,
#  'anti': 16,
#  'dumping': 15,
#  'duty': 9,
#  'imports': 188,
#  'brazilian': 22,
#  'frozen': 12,
#  'concentrated': 7,
#  'orange': 29,
#  'juice': 20,
#  'stephen': 6,
#  'vastagh': 4,
#  'investigator': 1,
#  'ministry': 91,
#  'tf': 2,
#  'forthcoming': 2,
#  'sell': 107,
#  'off': 70,
#  'meant': 6,
#  'third': 56,
#  'government': 240,
#  'programme': 11,
#  'less': 73,
#  'than': 299,
#  'nine': 99,
#  'institutes': 31,
#  'issued': 38,
#  'joint': 46,
#  'spring': 19,
#  'three': 221,
#  'kiel': 2,
#  'hamburg': 4,
#  'essen': 2,
#  'forecast': 74,
#  'gnp': 36,
#  'west': 177,
#  'berlin': 7,
#  'munich': 3,
#  'predicted': 29,
#  'one': 417,
#  'westcoast': 3,
#  'enable': 7,
#  'apply': 8,
#  'accumulated': 4,
#  'tax': 223,
#  'pools': 1,
#  'agip': 9,
#  'canada': 127,
#  'enhance': 6,
#  'cash': 129,
#  'flow': 15,
#  'acquired': 77,
#  'properties': 25,
#  'proxy': 5,
#  'materials': 41,
#  'maioled': 1,
#  'this': 529,
#  'quarter': 311,
#  'speech': 10,
#  'prepared': 20,
#  'delivery': 49,
#  'plans': 87,
#  'protect': 22,
#  'kuwaiti': 19,
#  'tankers': 10,
#  'iranian': 19,
#  'attack': 12,
#  'reagan': 74,
#  'people': 28,
#  'aware': 4,
#  'our': 84,
#  'interests': 34,
#  'alone': 9,
#  'protected': 10,
#  'pointed': 6,
#  'depressed': 8,
#  'reason': 25,
#  'current': 190,
#  'weakness': 16,
#  'economy': 110,
#  'later': 49,
#  'stronger': 7,
#  'domestic': 129,
#  'demand': 131,
#  'compensate': 5,
#  'setback': 1,
#  'happy': 4,
#  'brought': 10,
#  'forward': 24,
#  'marks': 68,
#  'planned': 42,
#  'january': 88,
#  'beginning': 24,
#  'faced': 5,
#  'political': 28,
#  'constraints': 5,
#  'getting': 8,
#  'such': 81,
#  'through': 92,
#  'upper': 8,
#  'house': 66,
#  'german': 92,
#  'parliament': 5,
#  'quoted': 30,
#  'stg': 176,
#  'midsession': 2,
#  'figure': 43,
#  'represents': 10,
#  'decline': 61,
#  'buffer': 29,
#  'aims': 4,
#  'keep': 29,
#  'within': 48,
#  'pre': 24,
#  'set': 75,
#  'range': 45,
#  'buying': 44,
#  'when': 144,
#  'selling': 30,
#  'bentsen': 5,
#  'coordinated': 2,
#  'billions': 1,
#  'debt': 108,
#  'service': 33,
#  'latin': 4,
#  'help': 69,
#  'ease': 17,
#  'protectionist': 15,
#  'pressures': 15,
#  'industrial': 92,
#  'proposal': 76,
#  'objectives': 5,
#  'maintain': 29,
#  'import': 55,
#  'levels': 73,
#  'idc': 4,
#  'official': 135,
#  'declined': 48,
#  'specify': 6,
#  'up': 313,
#  'talks': 88,
#  'economists': 53,
#  'spending': 38,
#  'target': 46,
#  'rand': 9,
#  'revenue': 24,
#  'budgeted': 4,
#  'around': 134,
#  'validly': 4,
#  'tendered': 18,
#  'represented': 7,
#  'outstanding': 84,
#  'supermarkets': 9,
#  'general': 77,
#  'america': 46,
#  'retain': 8,
#  'refusal': 4,
#  'if': 229,
#  'ansett': 8,
#  'offered': 42,
#  'sale': 107,
#  'choke': 2,
#  'modest': 21,
#  'economic': 197,
#  'expansion': 29,
#  'threaten': 4,
#  'recession': 15,
#  'bought': 70,
#  'band': 15,
#  'eight': 81,
#  'four': 145,
#  'paid': 53,
#  'assumption': 10,
#  'liabilities': 7,
#  'maize': 34,
#  'sown': 10,
#  'hectares': 24,
#  'season': 56,
#  'hopefully': 2,
#  'trend': 11,
#  'richardson': 2,
#  'greenshields': 1,
#  'economist': 26,
#  'susan': 1,
#  'clark': 8,
#  'toronto': 9,
#  'investment': 127,
#  'firm': 90,
#  'raises': 54,
#  'tvx': 3,
#  'tvxg': 2,
#  'o': 246,
#  'stake': 127,
#  'wedge': 1,
#  'inc': 577,
#  'houston': 15,
#  'raised': 51,
#  'broadcast': 5,
#  'common': 125,
#  'calls': 25,
#  'sino': 1,
#  'chilean': 1,
#  'venture': 36,
#  'paper': 21,
#  'european': 104,
#  'mediterranean': 3,
#  'area': 46,
#  'rig': 4,
#  'utilization': 3,
#  'ago': 108,
#  'upset': 1,
#  'compounded': 1,
#  'news': 44,
#  'sterling': 18,
#  'above': 53,
#  'england': 32,
#  'looks': 10,
#  'likely': 86,
#  'gilts': 2,
#  'offset': 26,
#  'impact': 46,
#  'money': 147,
#  'supply': 119,
#  'bp': 15,
#  'cut': 165,
#  'came': 18,
#  'result': 67,
#  'review': 34,
#  'occasioned': 1,
#  'substantial': 31,
#  'changes': 35,
#  'lpg': 2,
#  'congressional': 23,
#  'leaders': 14,
#  'complain': 1,
#  'consulted': 2,
#  'put': 51,
#  'flag': 9,
#  'charged': 9,
#  'lead': 69,
#  'into': 148,
#  'iran': 22,
#  'iraq': 32,
#  'war': 25,
#  'told': 198,
#  'al': 7,
#  'riyadh': 3,
#  'newspaper': 29,
#  'saudi': 38,
#  'arabia': 26,
#  'follows': 34,
#  'balanced': 7,
#  'petroleum': 73,
#  'expanded': 6,
#  'baht': 3,
#  'deputy': 12,
#  'representative': 17,
#  'michael': 11,
#  'smith': 9,
#  'makoto': 2,
#  'kuroda': 6,
#  'minister': 102,
#  'international': 185,
#  'industry': 160,
#  'miti': 12,
#  'due': 130,
#  'meet': 48,
#  'washington': 70,
#  'week': 286,
#  'effort': 26,
#  'dispute': 18,
#  'legislation': 20,
#  'supported': 9,
#  'congress': 39,
#  'democratic': 16,
#  'republican': 4,
#  'leadership': 3,
#  'administration': 35,
#  'required': 24,
#  'defense': 24,
#  'secretary': 41,
#  'caspar': 1,
#  'weinberger': 1,
#  'provide': 32,
#  'days': 121,
#  'enactment': 1,
#  'warships': 3,
#  'persian': 1,
#  'gulf': 72,
#  'questioned': 4,
#  'whether': 35,
#  'based': 116,
#  'entertainment': 15,
#  'marketing': 57,
#  'founded': 3,
#  'former': 22,
#  'electronics': 20,
#  'retailer': 6,
#  'buinesses': 1,
#  'primarily': 10,
#  'wholesale': 14,
#  'distributors': 6,
#  'expertise': 1,
#  'retailing': 5,
#  'merely': 3,
#  'trying': 20,
#  'drive': 17,
#  'crazy': 30,
#  'eddie': 31,
#  'already': 66,
#  'owns': 33,
#  'federal': 114,
#  'reserve': 88,
#  'board': 138,
#  'paul': 15,
#  'volcker': 20,
#  'repeatedly': 7,
#  'cutting': 17,
#  'red': 22,
#  'ink': 3,
#  'long': 90,
#  'way': 35,
#  'reduce': 64,
#  'massive': 11,
#  'downward': 10,
#  'pressure': 44,
#  'value': 79,
#  'profit': 270,
#  'almost': 25,
#  'consolidated': 24,
#  'net': 882,
#  'swiss': 34,
#  'francs': 53,
#  'drop': 44,
#  'cardenas': 2,
#  'cents': 69,
#  'lb': 16,
#  'october': 45,
#  'support': 55,
#  'jorge': 2,
#  'manager': 38,
#  'colombia': 18,
#  'national': 145,
#  'growers': 11,
#  'federation': 13,
#  'little': 50,
#  'reaction': 12,
#  'comex': 5,
#  'limit': 32,
#  'removal': 9,
#  'elimination': 7,
#  'limits': 10,
#  'precious': 4,
#  'metals': 16,
#  'contracts': 27,
#  'trading': 126,
#  'commodity': 42,
#  'exchange': 213,
#  'york': 75,
#  'appears': 12,
#  'effect': 35,
#  'mercer': 6,
#  'operating': 78,
#  'goodyear': 14,
#  'repurchase': 43,
#  'fend': 3,
#  'sir': 4,
#  'goldsmith': 4,
#  'hostile': 14,
#  'takeover': 77,
#  'bid': 108,
#  'lot': 12,
#  'given': 53,
#  'lindberg': 1,
#  'lind': 1,
#  'sales': 301,
#  'avg': 133,
#  'proceeds': 25,
#  'property': 15,
#  'discount': 52,
#  'penalty': 3,
#  'rather': 24,
#  'guiding': 2,
#  'since': 117,
#  'advances': 5,
#  'currently': 48,
#  'used': 60,
#  'liquidity': 24,
#  'ample': 4,
#  'traders': 107,
#  'london': 50,
#  'outcome': 10,
#  'tender': 118,
#  'hard': 28,
#  'predict': 6,
#  'award': 7,
#  'placing': 6,
#  'borg': 41,
#  'warner': 44,
#  'participant': 1,
#  'managers': 7,
#  'their': 181,
#  'positions': 16,
#  'reuter': 21,
#  'k': 84,
#  'assistance': 17,
#  'provided': 19,
#  'morning': 32,
#  'session': 19,
#  'takashi': 4,
#  'ishihara': 6,
#  'committee': 61,
#  'development': 74,
#  'accord': 46,
#  'prevent': 24,
#  'rising': 60,
#  'further': 140,
#  'extent': 7,
#  'fewer': 10,
#  'sdhares': 1,
#  'offer': 259,
#  'stockholders': 19,
#  'receive': 42,
#  'combination': 15,
#  'caesars': 9,
#  'unilever': 10,
#  'seeks': 14,
#  'buyer': 16,
#  'stauffer': 5,
#  'nv': 6,
#  'un': 3,
#  'prospectus': 2,
#  'bankers': 53,
#  'goldman': 2,
#  'sachs': 2,
#  'seeking': 36,
#  'recent': 77,
#  'chesebrough': 5,
#  ...}

# %%
# find the overall frequency of words in the corpus
counts = Counter(unigram_dict)
counts
# Out:
# Counter({'tranche': 4,
#          'increased': 59,
#          'tonne': 503,
#          'south': 100,
#          'korea': 33,
#          'added': 188,
#          'possible': 60,
#          'destination': 14,
#          'showa': 5,
#          'denko': 3,
#          'export': 343,
#          'aluminium': 19,
#          'casting': 2,
#          'equipment': 34,
#          'lt': 1200,
#          'ltd': 212,
#          'said': 3701,
#          'exporting': 9,
#          'billet': 1,
#          'technology': 49,
#          'country': 194,
#          'recently': 35,
#          'begun': 6,
#          'smelting': 5,
#          'note': 232,
#          'company': 840,
#          "'": 1683,
#          'full': 69,
#          'name': 47,
#          'gebrueder': 2,
#          'sulzer': 2,
#          'ag': 12,
#          'sulz': 1,
#          'z': 9,
#          'romero': 8,
#          'philippine': 26,
#          'end': 238,
#          'five': 208,
#          'year': 1113,
#          'coconut': 17,
#          'production': 229,
#          'cycle': 3,
#          'showed': 43,
#          'tended': 2,
#          'fall': 106,
#          'two': 368,
#          'successive': 3,
#          'good': 110,
#          'harvest': 19,
#          'lme': 18,
#          'warehouse': 9,
#          'stock': 455,
#          'near': 38,
#          'low': 69,
#          'fallen': 11,
#          'steadily': 4,
#          'record': 152,
#          'high': 123,
#          'reached': 46,
#          'february': 150,
#          'many': 43,
#          'major': 164,
#          'nation': 81,
#          'yesterday': 133,
#          'intervened': 8,
#          'heavily': 9,
#          'aid': 28,
#          'dlr': 188,
#          'miyazawa': 26,
#          'transaction': 76,
#          'structured': 3,
#          'merger': 94,
#          'liberty': 14,
#          'duly': 1,
#          'formed': 24,
#          'unit': 175,
#          'equimark': 5,
#          'ec': 136,
#          'failed': 15,
#          'follow': 10,
#          'consultation': 8,
#          'procedure': 18,
#          'laid': 3,
#          'lome': 1,
#          'convention': 1,
#          'regulates': 2,
#          'relation': 12,
#          'acp': 8,
#          'state': 207,
#          'bloc': 5,
#          'move': 105,
#          'could': 234,
#          'affect': 19,
#          'trade': 447,
#          'side': 15,
#          'dollar': 328,
#          'fell': 98,
#          'yen': 155,
#          'despite': 60,
#          'central': 152,
#          'bank': 614,
#          'intervention': 62,
#          'dealer': 131,
#          'george': 9,
#          'wimpey': 4,
#          'say': 197,
#          'benefit': 31,
#          'restructuring': 40,
#          'seen': 56,
#          'plc': 85,
#          'wmpy': 2,
#          'l': 57,
#          'outlook': 20,
#          'looked': 4,
#          'encouraging': 4,
#          'realised': 2,
#          'continuing': 45,
#          'dangerous': 6,
#          'go': 35,
#          'retaliatory': 4,
#          'route': 9,
#          'lead': 74,
#          'retaliation': 17,
#          'restriction': 23,
#          'indication': 9,
#          'u': 895,
#          'ship': 45,
#          'loaded': 2,
#          'raw': 21,
#          'sugar': 98,
#          'awaiting': 7,
#          'silvertown': 2,
#          'discharged': 2,
#          'tate': 5,
#          'lyle': 4,
#          'jeffrey': 3,
#          'leeds': 2,
#          'chemical': 61,
#          'convinced': 5,
#          'fed': 133,
#          'tightening': 11,
#          'policy': 139,
#          'prospect': 22,
#          'significant': 31,
#          'improvement': 29,
#          'unemployment': 29,
#          'situation': 24,
#          'next': 132,
#          'month': 333,
#          'average': 127,
#          'rate': 542,
#          'expected': 228,
#          'stabilize': 15,
#          'pct': 1509,
#          'similar': 32,
#          'last': 516,
#          'woodstock': 5,
#          'holding': 85,
#          'mln': 2521,
#          'every': 12,
#          'half': 88,
#          'week': 344,
#          'american': 111,
#          'dy': 3,
#          'salmonellosis': 2,
#          'complication': 1,
#          'arising': 2,
#          'incidence': 2,
#          'poisoning': 3,
#          'poultry': 21,
#          'past': 49,
#          'several': 63,
#          'self': 5,
#          'contained': 13,
#          'part': 88,
#          'overall': 30,
#          'group': 300,
#          'trans': 5,
#          'lux': 4,
#          'connecticut': 3,
#          'concern': 39,
#          'lease': 3,
#          'teleprinter': 1,
#          'display': 3,
#          'brokerage': 9,
#          'office': 45,
#          'airport': 6,
#          'public': 62,
#          'place': 28,
#          'crushing': 4,
#          'would': 747,
#          'commence': 3,
#          'labasa': 1,
#          'penang': 1,
#          'mill': 24,
#          'june': 197,
#          'lautoka': 2,
#          'rarawai': 1,
#          'brooklyn': 11,
#          'union': 94,
#          'fourth': 35,
#          'largest': 64,
#          'gas': 134,
#          'utility': 15,
#          'united': 136,
#          'purchased': 20,
#          'supply': 168,
#          'spot': 34,
#          'non': 83,
#          'contract': 89,
#          'market': 542,
#          'proportion': 2,
#          'estimated': 80,
#          'much': 70,
#          'higher': 134,
#          'analyst': 188,
#          'roth': 3,
#          'still': 95,
#          'interested': 15,
#          'acquiring': 18,
#          'turco': 2,
#          'atcor': 7,
#          'reviewing': 5,
#          'option': 37,
#          'potential': 22,
#          'buyer': 44,
#          'expressed': 15,
#          'interest': 237,
#          'consumer': 102,
#          'product': 210,
#          'business': 165,
#          'represent': 7,
#          'first': 371,
#          'victim': 3,
#          'price': 631,
#          'natural': 43,
#          'resource': 38,
#          'according': 41,
#          'system': 121,
#          'zimmerman': 9,
#          'mobil': 14,
#          'mob': 5,
#          'north': 34,
#          'sea': 7,
#          'find': 17,
#          'corp': 500,
#          'wildcat': 1,
#          'well': 83,
#          'block': 20,
#          'british': 61,
#          'flowed': 2,
#          'cubic': 18,
#          'foot': 20,
#          'per': 274,
#          'day': 227,
#          'depth': 3,
#          'asset': 140,
#          'uam': 1,
#          'completes': 23,
#          'acquisition': 190,
#          'management': 103,
#          'completed': 50,
#          'rice': 50,
#          'hall': 4,
#          'james': 28,
#          'associate': 43,
#          'san': 26,
#          'diego': 4,
#          'undisclosed': 34,
#          'term': 173,
#          'includes': 102,
#          'lazere': 3,
#          'loan': 194,
#          'portfolio': 4,
#          'including': 78,
#          'miami': 4,
#          'finland': 6,
#          'neste': 3,
#          'oy': 3,
#          'whose': 14,
#          'turnover': 27,
#          'billion': 857,
#          'dlrs': 1704,
#          'extensive': 4,
#          'experience': 8,
#          'mtbe': 6,
#          'arrangement': 22,
#          'financing': 47,
#          'yet': 43,
#          'made': 139,
#          'assurance': 8,
#          'received': 56,
#          'hmo': 2,
#          'asked': 58,
#          'japan': 344,
#          'committed': 8,
#          'fresh': 18,
#          'measure': 68,
#          'statement': 144,
#          'exceptional': 7,
#          'among': 31,
#          'seven': 115,
#          'appreciated': 2,
#          'currency': 176,
#          'largely': 13,
#          'stable': 28,
#          'initial': 28,
#          'distribution': 28,
#          'take': 120,
#          'form': 30,
#          'dividend': 123,
#          'cumulative': 23,
#          'redeemable': 5,
#          'retractable': 2,
#          'class': 24,
#          'series': 39,
#          'preferred': 61,
#          'share': 808,
#          'entitling': 2,
#          'holder': 30,
#          'monthly': 30,
#          'floating': 8,
#          'prime': 63,
#          'retraction': 1,
#          'aristech': 3,
#          'ar': 1,
#          'st': 223,
#          'qtr': 373,
#          'shr': 500,
#          'estimate': 71,
#          'right': 75,
#          'chairman': 108,
#          'chief': 33,
#          'executive': 52,
#          'officer': 32,
#          'thomas': 4,
#          'marshall': 9,
#          'fiscal': 68,
#          'earnings': 145,
#          'hint': 3,
#          'announcement': 46,
#          'might': 49,
#          'may': 435,
#          'buy': 163,
#          'wheat': 148,
#          'valued': 11,
#          'april': 376,
#          'august': 31,
#          'port': 47,
#          'september': 39,
#          'department': 151,
#          'magellan': 7,
#          'disclose': 12,
#          'agreement': 248,
#          'fee': 21,
#          'trust': 48,
#          'banking': 41,
#          'service': 92,
#          'rose': 191,
#          'earlier': 135,
#          'adam': 6,
#          'express': 6,
#          'co': 303,
#          'adx': 1,
#          'march': 246,
#          'v': 1849,
#          'shrs': 134,
#          'lastest': 1,
#          'capital': 89,
#          'gain': 115,
#          'ct': 1027,
#          'december': 74,
#          'china': 91,
#          'resume': 16,
#          'ussr': 17,
#          'repair': 9,
#          'gap': 10,
#          'resumed': 4,
#          'soviet': 40,
#          'break': 16,
#          'caused': 32,
#          'ideological': 1,
#          'split': 63,
#          'seasonally': 28,
#          'adjusted': 74,
#          'index': 39,
#          'input': 6,
#          'rise': 227,
#          'rash': 1,
#          'advertising': 5,
#          'solicit': 3,
#          'new': 396,
#          'helped': 16,
#          'homebuyers': 1,
#          'become': 36,
#          'even': 39,
#          'choosier': 1,
#          'lender': 11,
#          'concede': 1,
#          'forced': 13,
#          'undercut': 2,
#          'totally': 3,
#          'unadjusted': 12,
#          'figure': 141,
#          'show': 63,
#          'deficit': 186,
#          'revised': 38,
#          'compared': 131,
#          'statistic': 34,
#          'producer': 102,
#          'heavy': 33,
#          'heating': 13,
#          'oil': 487,
#          'liquefied': 3,
#          'coffee': 59,
#          'cheaper': 6,
#          'xebec': 6,
#          'also': 329,
#          'expects': 86,
#          'revenue': 82,
#          'total': 238,
#          'ncr': 9,
#          'achieving': 2,
#          'recuperation': 2,
#          'credit': 153,
#          'cannot': 22,
#          'done': 19,
#          'overnight': 16,
#          'azpurua': 10,
#          'television': 21,
#          'interview': 18,
#          'commonwealth': 13,
#          'cut': 234,
#          'australia': 47,
#          'lower': 133,
#          'lending': 14,
#          'effective': 71,
#          'progress': 19,
#          'main': 34,
#          'sector': 63,
#          'except': 14,
#          'remain': 48,
#          'present': 34,
#          'level': 150,
#          'report': 189,
#          'fluor': 3,
#          'applied': 10,
#          'engineering': 6,
#          'construct': 2,
#          'modular': 1,
#          'section': 7,
#          'deliver': 5,
#          'ge': 6,
#          'waterford': 1,
#          'n': 69,
#          'silicone': 1,
#          'division': 60,
#          'plant': 74,
#          'merchant': 14,
#          'fear': 16,
#          'large': 59,
#          'tonnage': 8,
#          'delivered': 8,
#          'future': 95,
#          'possibly': 16,
#          'disrupt': 1,
#          'physical': 8,
#          'franc': 72,
#          'carry': 18,
#          'warrant': 29,
#          'today': 225,
#          'itc': 16,
#          'ruling': 26,
#          'consistent': 15,
#          'commerce': 34,
#          'final': 40,
#          'activates': 1,
#          'anti': 16,
#          'dumping': 15,
#          'duty': 19,
#          'import': 243,
#          'brazilian': 22,
#          'frozen': 12,
#          'concentrated': 7,
#          'orange': 33,
#          'juice': 22,
#          'stephen': 6,
#          'vastagh': 4,
#          'investigator': 1,
#          'ministry': 92,
#          'tf': 2,
#          'forthcoming': 2,
#          'sell': 132,
#          'meant': 6,
#          'third': 61,
#          'government': 246,
#          'programme': 11,
#          'less': 73,
#          'nine': 99,
#          'institute': 59,
#          'issued': 38,
#          'joint': 46,
#          'spring': 19,
#          'three': 221,
#          'kiel': 2,
#          'hamburg': 4,
#          'essen': 2,
#          'forecast': 94,
#          'gnp': 36,
#          'west': 177,
#          'berlin': 7,
#          'munich': 3,
#          'predicted': 29,
#          'one': 418,
#          'westcoast': 3,
#          'enable': 7,
#          'apply': 8,
#          'accumulated': 4,
#          'tax': 250,
#          'pool': 4,
#          'agip': 9,
#          'canada': 127,
#          'enhance': 6,
#          'cash': 129,
#          'flow': 21,
#          'acquired': 77,
#          'property': 40,
#          'proxy': 5,
#          'material': 54,
#          'maioled': 1,
#          'quarter': 315,
#          'speech': 10,
#          'prepared': 20,
#          'delivery': 55,
#          'plan': 203,
#          'protect': 22,
#          'kuwaiti': 19,
#          'tanker': 17,
#          'iranian': 22,
#          'attack': 14,
#          'reagan': 74,
#          'people': 30,
#          'aware': 4,
#          'alone': 9,
#          'protected': 10,
#          'pointed': 6,
#          'depressed': 8,
#          'reason': 37,
#          'current': 190,
#          'weakness': 16,
#          'economy': 126,
#          'later': 49,
#          'stronger': 7,
#          'domestic': 129,
#          'demand': 142,
#          'compensate': 5,
#          'setback': 2,
#          'happy': 4,
#          'brought': 10,
#          'forward': 24,
#          'mark': 102,
#          'planned': 42,
#          'january': 88,
#          'beginning': 24,
#          'faced': 5,
#          'political': 28,
#          'constraint': 5,
#          'getting': 8,
#          'upper': 8,
#          'house': 74,
#          'german': 94,
#          'parliament': 5,
#          'quoted': 30,
#          'stg': 176,
#          'midsession': 2,
#          'represents': 10,
#          'decline': 69,
#          'buffer': 29,
#          'aim': 10,
#          'keep': 29,
#          'within': 48,
#          'pre': 24,
#          'set': 123,
#          'range': 58,
#          'buying': 44,
#          'selling': 30,
#          'bentsen': 5,
#          'coordinated': 2,
#          'debt': 109,
#          'latin': 4,
#          'help': 71,
#          'ease': 17,
#          'protectionist': 15,
#          'pressure': 59,
#          'industrial': 92,
#          'proposal': 94,
#          'objective': 10,
#          'maintain': 29,
#          'idc': 4,
#          'official': 285,
#          'declined': 48,
#          'specify': 6,
#          'talk': 94,
#          'economist': 79,
#          'spending': 38,
#          'target': 54,
#          'rand': 9,
#          'budgeted': 4,
#          'around': 134,
#          'validly': 4,
#          'tendered': 18,
#          'represented': 7,
#          'outstanding': 84,
#          'supermarket': 9,
#          'general': 77,
#          'america': 46,
#          'retain': 8,
#          'refusal': 4,
#          'ansett': 8,
#          'offered': 42,
#          'sale': 408,
#          'choke': 2,
#          'modest': 21,
#          'economic': 197,
#          'expansion': 30,
#          'threaten': 4,
#          'recession': 15,
#          'bought': 70,
#          'band': 15,
#          'eight': 81,
#          'four': 145,
#          'paid': 53,
#          'assumption': 11,
#          'liability': 9,
#          'maize': 34,
#          'sown': 10,
#          'hectare': 30,
#          'season': 63,
#          'hopefully': 2,
#          'trend': 17,
#          'richardson': 2,
#          'greenshields': 1,
#          'susan': 1,
#          'clark': 8,
#          'toronto': 9,
#          'investment': 150,
#          'firm': 139,
#          'raise': 101,
#          'tvx': 3,
#          'tvxg': 2,
#          'stake': 130,
#          'wedge': 1,
#          'inc': 577,
#          'houston': 15,
#          'raised': 51,
#          'broadcast': 5,
#          'common': 128,
#          'call': 51,
#          'sino': 1,
#          'chilean': 1,
#          'venture': 44,
#          'paper': 23,
#          'european': 105,
#          'mediterranean': 3,
#          'area': 79,
#          'rig': 11,
#          'utilization': 3,
#          'ago': 108,
#          'upset': 1,
#          'compounded': 1,
#          'news': 44,
#          'sterling': 18,
#          'england': 32,
#          'look': 24,
#          'likely': 86,
#          'gilt': 4,
#          'offset': 26,
#          'impact': 46,
#          'money': 147,
#          'bp': 15,
#          'came': 18,
#          'result': 138,
#          'review': 37,
#          'occasioned': 1,
#          'substantial': 31,
#          'change': 100,
#          'lpg': 2,
#          'congressional': 23,
#          'leader': 24,
#          'complain': 1,
#          'consulted': 2,
#          'put': 55,
#          'flag': 12,
#          'charged': 9,
#          'iran': 22,
#          'iraq': 32,
#          'war': 25,
#          'told': 198,
#          'al': 8,
#          'riyadh': 3,
#          'newspaper': 33,
#          'saudi': 39,
#          'arabia': 26,
#          'follows': 34,
#          'balanced': 7,
#          'petroleum': 74,
#          'expanded': 6,
#          'baht': 3,
#          'deputy': 12,
#          'representative': 34,
#          'michael': 13,
#          'smith': 9,
#          'makoto': 2,
#          'kuroda': 6,
#          'minister': 152,
#          'international': 185,
#          'industry': 248,
#          'miti': 12,
#          'due': 130,
#          'meet': 51,
#          'washington': 70,
#          'effort': 48,
#          'dispute': 22,
#          'legislation': 20,
#          'supported': 9,
#          'congress': 39,
#          'democratic': 16,
#          'republican': 8,
#          'leadership': 3,
#          'administration': 35,
#          'required': 24,
#          'defense': 24,
#          'secretary': 41,
#          'caspar': 1,
#          'weinberger': 1,
#          'provide': 32,
#          'enactment': 1,
#          'warship': 4,
#          'persian': 1,
#          'gulf': 72,
#          'questioned': 4,
#          'whether': 35,
#          'based': 116,
#          'entertainment': 15,
#          'marketing': 58,
#          'founded': 3,
#          'former': 22,
#          'electronics': 20,
#          'retailer': 13,
#          'buinesses': 1,
#          'primarily': 10,
#          'wholesale': 14,
#          'distributor': 10,
#          'expertise': 1,
#          'retailing': 5,
#          'merely': 3,
#          'trying': 20,
#          'drive': 19,
#          'crazy': 30,
#          'eddie': 31,
#          'already': 66,
#          'owns': 33,
#          'federal': 114,
#          'reserve': 213,
#          'board': 144,
#          'paul': 15,
#          'volcker': 20,
#          'repeatedly': 7,
#          'cutting': 17,
#          'red': 22,
#          'ink': 3,
#          'long': 90,
#          'way': 46,
#          'reduce': 64,
#          'massive': 11,
#          'downward': 10,
#          'value': 96,
#          'profit': 342,
#          'almost': 25,
#          'consolidated': 24,
#          'net': 882,
#          'swiss': 34,
#          'drop': 48,
#          'cardenas': 2,
#          'cent': 83,
#          'lb': 33,
#          'october': 45,
#          'support': 60,
#          'jorge': 2,
#          'manager': 45,
#          'colombia': 18,
#          'national': 145,
#          'grower': 13,
#          'federation': 13,
#          'little': 50,
#          'reaction': 13,
#          'comex': 5,
#          'limit': 42,
#          'removal': 9,
#          'elimination': 7,
#          'precious': 4,
#          'metal': 42,
#          'trading': 126,
#          'commodity': 65,
#          'exchange': 216,
#          'york': 75,
#          'appears': 12,
#          'effect': 42,
#          'mercer': 6,
#          'operating': 78,
#          'goodyear': 14,
#          'repurchase': 59,
#          'fend': 3,
#          'sir': 4,
#          'goldsmith': 4,
#          'hostile': 14,
#          'takeover': 81,
#          'bid': 137,
#          'lot': 15,
#          'given': 53,
#          'lindberg': 1,
#          'lind': 1,
#          'avg': 133,
#          'proceeds': 25,
#          'discount': 62,
#          'penalty': 5,
#          'rather': 24,
#          'guiding': 2,
#          'since': 117,
#          'advance': 14,
#          'currently': 48,
#          'used': 60,
#          'liquidity': 24,
#          'ample': 4,
#          'trader': 120,
#          'london': 50,
#          'outcome': 10,
#          'tender': 131,
#          'hard': 28,
#          'predict': 6,
#          'award': 10,
#          'placing': 6,
#          'borg': 41,
#          'warner': 44,
#          'participant': 5,
#          'position': 70,
#          'reuter': 21,
#          'k': 84,
#          'assistance': 17,
#          'provided': 19,
#          'morning': 32,
#          'session': 20,
#          'takashi': 4,
#          'ishihara': 6,
#          'committee': 65,
#          'development': 80,
#          'accord': 51,
#          'prevent': 24,
#          'rising': 60,
#          'extent': 7,
#          'fewer': 10,
#          'sdhares': 1,
#          'offer': 295,
#          'stockholder': 22,
#          'receive': 42,
#          'combination': 17,
#          'caesar': 9,
#          'unilever': 10,
#          'seek': 29,
#          'stauffer': 5,
#          'nv': 6,
#          'un': 3,
#          'prospectus': 2,
#          'banker': 63,
#          'goldman': 2,
#          'sachs': 2,
#          'seeking': 36,
#          'recent': 77,
#          'chesebrough': 5,
#          'pond': 2,
#          'spokesman': 134,
#          'italian': 23,
#          'daily': 56,
#          'la': 18,
#          'repubblica': 1,
#          'gemina': 2,
#          'lira': 29,
#          'shareholding': 3,
#          'hick': 4,
#          'haas': 7,
#          'spectradyne': 4,
#          'spdy': 1,
#          'fund': 120,
#          'spi': 1,
#          'consisting': 4,
#          'acadia': 1,
#          'partner': 58,
#          'lp': 5,
#          'commitment': 48,
#          'senior': 30,
#          'needed': 43,
#          'complete': 18,
#          'proposed': 84,
#          'security': 150,
#          'samjens': 13,
#          'lawyer': 13,
#          'discounted': 4,
#          'trip': 7,
#          'attempt': 21,
#          'farm': 74,
#          'key': 44,
#          'gatt': 18,
#          'member': 70,
#          'addition': 33,
#          'sealy': 7,
#          'redeemed': 1,
#          'held': 87,
#          'michigan': 6,
#          'thus': 12,
#          'increasing': 29,
#          'fargo': 9,
#          'wfc': 1,
#          'deposit': 70,
#          'filing': 41,
#          'wet': 3,
#          'barrel': 104,
#          'unprofitable': 3,
#          'world': 142,
#          'cocoa': 60,
#          'interesting': 4,
#          'commented': 1,
#          'delegate': 10,
#          'representing': 10,
#          'cpa': 6,
#          'cabinet': 14,
#          'give': 48,
#          'approval': 61,
#          'thursday': 12,
#          'tariff': 95,
#          'implemented': 6,
#          'starting': 19,
#          'cominco': 23,
#          'clt': 3,
#          'reject': 11,
#          'steelworker': 10,
#          'local': 57,
#          'strike': 41,
#          'rejected': 26,
#          'tentative': 6,
#          'g': 73,
#          'affirmed': 2,
#          'appropriate': 17,
#          'carefully': 5,
#          'worded': 1,
#          'boost': 40,
#          'particularly': 25,
#          'uccel': 20,
#          'shareholder': 140,
#          'computer': 84,
#          'approximately': 13,
#          'case': 39,
#          'related': 26,
#          'airline': 13,
#          'awal': 2,
#          'party': 46,
#          'voicing': 1,
#          'opposition': 14,
#          'purchase': 102,
#          'issue': 93,
#          'sears': 9,
#          'lex': 10,
#          'ordinary': 23,
#          'begin': 50,
#          'time': 121,
#          'prudhoe': 2,
#          'bay': 3,
#          'without': 38,
#          'endangering': 1,
#          'caribou': 1,
#          'wildlife': 2,
#          'dome': 133,
#          'encor': 6,
#          'budget': 89,
#          'portrayed': 1,
#          'mildly': 1,
#          'contractionary': 1,
#          'doubling': 3,
#          'nominal': 7,
#          'dinar': 12,
#          'underlying': 20,
#          'back': 44,
#          'late': 39,
#          'second': 65,
#          'period': 151,
#          'ended': 118,
#          'wednesday': 33,
#          'discussed': 10,
#          'problem': 70,
#          'developing': 15,
#          'proceed': 4,
#          ...})

# %%
# vocabulary size
total_count = len(unigram_dict)
total_count
# Out:
# 10320

# %%
# relative frequencies of each word
for word in counts:
    counts[word] /= float(total_count)

counts
# Out:
# Counter({'but': 0.04544666088464874,
#          'now': 0.012142237640936688,
#          'both': 0.006071118820468344,
#          'tranches': 0.00017346053772766696,
#          'have': 0.03842150910667823,
#          'been': 0.026539462272333045,
#          'increased': 0.0051170858629661755,
#          'by': 0.09627059843885516,
#          'tonnes': 0.03842150910667823,
#          'to': 0.4422376409366869,
#          'with': 0.07918473547267997,
#          'south': 0.008673026886383347,
#          'korea': 0.002862098872506505,
#          'added': 0.016305290546400692,
#          'as': 0.06131830008673027,
#          'a': 0.308846487424111,
#          'possible': 0.005203816131830009,
#          'destination': 0.0005203816131830009,
#          'showa': 0.0004336513443191674,
#          'denko': 0.00026019080659150045,
#          'exports': 0.01925411968777103,
#          'aluminium': 0.001647875108412836,
#          'casting': 0.00017346053772766696,
#          'equipment': 0.002948829141370338,
#          'lt': 0.10407632263660017,
#          'ltd': 0.018386816999132697,
#          'said': 0.3209887250650477,
#          'it': 0.1367736339982654,
#          'is': 0.0981786643538595,
#          'exporting': 0.0007805724197745013,
#          'billet': 8.673026886383348e-05,
#          'and': 0.3151777970511709,
#          'technology': 0.002862098872506505,
#          'countries': 0.009887250650477016,
#          'that': 0.09566348655680833,
#          'recently': 0.003035559410234172,
#          'begun': 0.0005203816131830009,
#          'smelting': 0.0004336513443191674,
#          'note': 0.018126626192541198,
#          'company': 0.0590633130962706,
#          "'": 0.14596704249783174,
#          's': 0.19609713790112748,
#          'full': 0.00598438855160451,
#          'name': 0.003816131830008673,
#          'gebrueder': 0.00017346053772766696,
#          'sulzer': 0.00017346053772766696,
#          'ag': 0.0010407632263660018,
#          'sulz': 8.673026886383348e-05,
#          'z': 0.0007805724197745013,
#          'romero': 0.0006938421509106678,
#          'the': 0.8718993928881179,
#          'philippines': 0.001474414570685169,
#          'was': 0.07970511708586296,
#          'at': 0.09219427580225499,
#          'end': 0.0194275802254987,
#          'of': 0.46487424111014747,
#          'five': 0.018039895923677364,
#          'year': 0.08586296617519515,
#          'coconut': 0.0013009540329575022,
#          'production': 0.0196877710320902,
#          'cycle': 0.00017346053772766696,
#          'which': 0.04518647007805724,
#          'showed': 0.0037294015611448396,
#          'tended': 0.00017346053772766696,
#          'fall': 0.007632263660017346,
#          'after': 0.02593235039028621,
#          'two': 0.03191673894189072,
#          'successive': 0.00026019080659150045,
#          'years': 0.010667823070251518,
#          'good': 0.0046834345186470075,
#          'harvests': 0.0003469210754553339,
#          'lme': 0.0015611448395490026,
#          'warehouse': 0.0006071118820468344,
#          'stocks': 0.011535125758889852,
#          'are': 0.04267129228100607,
#          'near': 0.003295750216825672,
#          'low': 0.005290546400693842,
#          'having': 0.0013009540329575022,
#          'fallen': 0.0009540329575021682,
#          'steadily': 0.0003469210754553339,
#          'from': 0.09705117085862966,
#          'record': 0.013009540329575022,
#          'high': 0.010494362532523852,
#          'reached': 0.00398959236773634,
#          'in': 0.3568950563746748,
#          'february': 0.013009540329575022,
#          'many': 0.0037294015611448396,
#          'major': 0.01422376409366869,
#          'nations': 0.005030355594102341,
#          'yesterday': 0.011535125758889852,
#          'intervened': 0.0006938421509106678,
#          'heavily': 0.0007805724197745013,
#          'aid': 0.0023417172593235037,
#          'dlr': 0.016305290546400692,
#          'miyazawa': 0.0022549869904596705,
#          'transaction': 0.004770164787510842,
#          'structured': 0.00026019080659150045,
#          'merger': 0.00797918473547268,
#          'liberty': 0.0012142237640936687,
#          'duly': 8.673026886383348e-05,
#          'formed': 0.0020815264527320036,
#          'unit': 0.011708586296617519,
#          'equimark': 0.0004336513443191674,
#          'they': 0.03590633130962706,
#          'ec': 0.011795316565481353,
#          'failed': 0.0013009540329575022,
#          'follow': 0.0008673026886383347,
#          'consultation': 0.0004336513443191674,
#          'procedures': 0.0013876843018213356,
#          'laid': 0.00026019080659150045,
#          'down': 0.009540329575021683,
#          'lome': 8.673026886383348e-05,
#          'convention': 8.673026886383348e-05,
#          'regulates': 0.00017346053772766696,
#          'relations': 0.0007805724197745013,
#          'between': 0.01248915871639202,
#          'acp': 0.0006938421509106678,
#          'states': 0.010234171725932351,
#          'bloc': 0.0004336513443191674,
#          'for': 0.17883781439722463,
#          'moves': 0.0022549869904596705,
#          'could': 0.020294882914137034,
#          'affect': 0.001474414570685169,
#          'trade': 0.037814397224631396,
#          'sides': 0.0007805724197745013,
#          'dollar': 0.024718126626192542,
#          'fell': 0.00849956634865568,
#          'yen': 0.013443191673894189,
#          'despite': 0.005203816131830009,
#          'central': 0.013183000867302688,
#          'bank': 0.04336513443191674,
#          'intervention': 0.005377276669557675,
#          'dealers': 0.009540329575021683,
#          'george': 0.0006938421509106678,
#          'wimpey': 0.0003469210754553339,
#          'says': 0.010147441457068517,
#          'benefits': 0.0015611448395490026,
#          'restructuring': 0.003469210754553339,
#          'seen': 0.004856895056374675,
#          'plc': 0.007372072853425846,
#          'wmpy': 0.00017346053772766696,
#          'l': 0.004943625325238508,
#          'outlook': 0.0017346053772766695,
#          'looked': 0.0003469210754553339,
#          'encouraging': 0.0003469210754553339,
#          'realised': 0.00017346053772766696,
#          'continuing': 0.0039028620988725065,
#          'very': 0.004509973980919341,
#          'dangerous': 0.0005203816131830009,
#          'go': 0.0027753686036426713,
#          'retaliatory': 0.0003469210754553339,
#          'route': 0.0003469210754553339,
#          'he': 0.06686903729401561,
#          'because': 0.014917606244579358,
#          'leads': 0.0004336513443191674,
#          'more': 0.025238508239375543,
#          'retaliation': 0.001474414570685169,
#          'restrictions': 0.0017346053772766695,
#          'an': 0.05897658282740677,
#          'indication': 0.0005203816131830009,
#          'u': 0.07502168256721596,
#          'other': 0.022636600173460537,
#          'ships': 0.0026886383347788376,
#          'loaded': 0.00017346053772766696,
#          'raw': 0.001647875108412836,
#          'sugar': 0.00849956634865568,
#          'awaiting': 0.0006071118820468344,
#          'silvertown': 0.00017346053772766696,
#          'be': 0.0805724197745013,
#          'discharged': 0.00017346053772766696,
#          'tate': 0.0004336513443191674,
#          'lyle': 0.0003469210754553339,
#          'jeffrey': 0.00026019080659150045,
#          'leeds': 0.00017346053772766696,
#          'chemical': 0.004336513443191674,
#          'had': 0.03538594969644406,
#          'not': 0.055941023417172595,
#          'convinced': 0.0004336513443191674,
#          'fed': 0.011535125758889852,
#          'tightening': 0.0009540329575021682,
#          'policy': 0.010234171725932351,
#          'there': 0.015091066782307025,
#          'no': 0.020121422376409365,
#          'prospect': 0.00017346053772766696,
#          'any': 0.009540329575021683,
#          'significant': 0.0026886383347788376,
#          'improvement': 0.0022549869904596705,
#          'unemployment': 0.0025151777970511707,
#          'situation': 0.00199479618386817,
#          'over': 0.01647875108412836,
#          'next': 0.01144839549002602,
#          'months': 0.011361665221162186,
#          'average': 0.010841283607979185,
#          'rate': 0.02740676496097138,
#          'expected': 0.019774501300954032,
#          'stabilize': 0.0013009540329575022,
#          'pct': 0.13087597571552473,
#          'similar': 0.0027753686036426713,
#          'last': 0.04475281873373808,
#          'woodstock': 0.0004336513443191674,
#          'holding': 0.0037294015611448396,
#          'mln': 0.2186470078057242,
#          'state': 0.00771899392888118,
#          'she': 0.0023417172593235037,
#          'every': 0.0010407632263660018,
#          'half': 0.007632263660017346,
#          'weeks': 0.005030355594102341,
#          'american': 0.009280138768430183,
#          'dies': 0.00026019080659150045,
#          'salmonellosis': 0.00017346053772766696,
#          'or': 0.037814397224631396,
#          'complications': 8.673026886383348e-05,
#          'arising': 0.00017346053772766696,
#          'incidence': 0.00017346053772766696,
#          'poisoning': 0.00026019080659150045,
#          'poultry': 0.001821335646140503,
#          'has': 0.06392020815264528,
#          'past': 0.00424978317432784,
#          'several': 0.005464006938421509,
#          'self': 0.0004336513443191674,
#          'contained': 0.0011274934952298352,
#          'part': 0.006157849089332177,
#          'overall': 0.0026019080659150044,
#          'group': 0.02419774501300954,
#          'trans': 0.0004336513443191674,
#          'lux': 0.0003469210754553339,
#          'connecticut': 0.00026019080659150045,
#          'concern': 0.0026886383347788376,
#          'leases': 0.00026019080659150045,
#          'teleprinters': 8.673026886383348e-05,
#          'display': 0.00026019080659150045,
#          'units': 0.003469210754553339,
#          'brokerage': 0.0007805724197745013,
#          'offices': 0.0006071118820468344,
#          'airports': 8.673026886383348e-05,
#          'public': 0.005290546400693842,
#          'places': 0.00026019080659150045,
#          'crushing': 0.00017346053772766696,
#          'would': 0.0647875108412836,
#          'commence': 0.00026019080659150045,
#          'labasa': 8.673026886383348e-05,
#          'penang': 8.673026886383348e-05,
#          'mills': 0.0013009540329575022,
#          'on': 0.11361665221162186,
#          'june': 0.017085862966175196,
#          'lautoka': 0.00017346053772766696,
#          'rarawai': 8.673026886383348e-05,
#          'brooklyn': 0.0009540329575021682,
#          'union': 0.007285342584562012,
#          'fourth': 0.003035559410234172,
#          'largest': 0.005550737207285343,
#          'gas': 0.01144839549002602,
#          'utility': 0.0005203816131830009,
#          'united': 0.011795316565481353,
#          'purchased': 0.0017346053772766695,
#          'its': 0.09479618386816999,
#          'supplies': 0.00424978317432784,
#          'spot': 0.002862098872506505,
#          'non': 0.007198612315698179,
#          'contract': 0.005377276669557675,
#          'market': 0.034258456201214225,
#          'proportion': 0.00017346053772766696,
#          'estimated': 0.006938421509106678,
#          'much': 0.006071118820468344,
#          'higher': 0.011621856027753686,
#          'analysts': 0.012315698178664354,
#          'while': 0.011535125758889852,
#          'roth': 0.00026019080659150045,
#          'still': 0.00823937554206418,
#          'interested': 0.0013009540329575022,
#          'acquiring': 0.0015611448395490026,
#          'turco': 0.00017346053772766696,
#          'atcor': 0.0006071118820468344,
#          'reviewing': 0.0004336513443191674,
#          'options': 0.0017346053772766695,
#          'potential': 0.0019080659150043364,
#          'buyers': 0.0024284475281873374,
#          'who': 0.006591500433651344,
#          'expressed': 0.0013009540329575022,
#          'interest': 0.017606244579358197,
#          'consumer': 0.006504770164787511,
#          'products': 0.013616652211621855,
#          'businesses': 0.003295750216825672,
#          'we': 0.01821335646140503,
#          'represent': 0.0006071118820468344,
#          'first': 0.03217692974848222,
#          'victim': 8.673026886383348e-05,
#          'move': 0.006851691240242845,
#          'price': 0.02792714657415438,
#          'natural': 0.0037294015611448396,
#          'resources': 0.002948829141370338,
#          'according': 0.0035559410234171727,
#          'system': 0.0067649609713790115,
#          'zimmerman': 0.0007805724197745013,
#          'mobil': 0.0012142237640936687,
#          'mob': 0.0004336513443191674,
#          'north': 0.002948829141370338,
#          'sea': 0.0006071118820468344,
#          'find': 0.001474414570685169,
#          'corp': 0.04336513443191674,
#          'wildcat': 8.673026886383348e-05,
#          'well': 0.005897658282740676,
#          'block': 0.0012142237640936687,
#          'british': 0.005290546400693842,
#          'flowed': 0.00017346053772766696,
#          'cubic': 0.0015611448395490026,
#          'feet': 0.0015611448395490026,
#          'per': 0.023764093668690374,
#          'day': 0.009193408499566348,
#          'depths': 8.673026886383348e-05,
#          'asset': 0.0012142237640936687,
#          'uam': 8.673026886383348e-05,
#          'completes': 0.00199479618386817,
#          'acquisition': 0.013876843018213356,
#          'management': 0.008846487424111016,
#          'completed': 0.004336513443191674,
#          'rice': 0.004336513443191674,
#          'hall': 0.0003469210754553339,
#          'james': 0.0024284475281873374,
#          'associates': 0.003209019947961839,
#          'san': 0.0022549869904596705,
#          'diego': 0.0003469210754553339,
#          'undisclosed': 0.002948829141370338,
#          'terms': 0.007111882046834345,
#          'includes': 0.008846487424111016,
#          'most': 0.007111882046834345,
#          'lazere': 0.00026019080659150045,
#          'loan': 0.00823937554206418,
#          'portfolio': 0.00026019080659150045,
#          'assets': 0.010928013876843019,
#          'including': 0.0067649609713790115,
#          'miami': 0.0003469210754553339,
#          'office': 0.003295750216825672,
#          'finland': 0.0005203816131830009,
#          'neste': 0.00026019080659150045,
#          'oy': 0.00026019080659150045,
#          'whose': 0.0012142237640936687,
#          'turnover': 0.0023417172593235037,
#          'billion': 0.07424111014744146,
#          'dlrs': 0.14778837814397225,
#          'extensive': 0.0003469210754553339,
#          'experience': 0.0006071118820468344,
#          'mtbe': 0.0005203816131830009,
#          'arrangements': 0.0008673026886383347,
#          'financing': 0.004076322636600173,
#          'yet': 0.0037294015611448396,
#          'made': 0.012055507372072853,
#          'can': 0.00849956634865568,
#          'assurance': 0.0005203816131830009,
#          'will': 0.06860364267129228,
#          'received': 0.004856895056374675,
#          'hmo': 0.00017346053772766696,
#          'asked': 0.005030355594102341,
#          'why': 0.0012142237640936687,
#          'only': 0.012662619254119687,
#          'japan': 0.029835212489158717,
#          'committed': 0.0006938421509106678,
#          'fresh': 0.0015611448395490026,
#          'measures': 0.0046834345186470075,
#          'statement': 0.011621856027753686,
#          'exceptional': 0.0006071118820468344,
#          'among': 0.0026886383347788376,
#          'seven': 0.00997398091934085,
#          'appreciated': 0.00017346053772766696,
#          'against': 0.018820468343451864,
#          'currencies': 0.0039028620988725065,
#          'largely': 0.0011274934952298352,
#          'stable': 0.0024284475281873374,
#          'initial': 0.0024284475281873374,
#          'distribution': 0.002168256721595837,
#          'take': 0.009453599306157849,
#          'form': 0.0020815264527320036,
#          'stock': 0.02792714657415438,
#          'dividend': 0.009366869037294015,
#          'cumulative': 0.00199479618386817,
#          'redeemable': 0.0004336513443191674,
#          'retractable': 0.00017346053772766696,
#          'class': 0.00199479618386817,
#          'series': 0.0033824804856895057,
#          'preferred': 0.005290546400693842,
#          'shares': 0.03555941023417172,
#          'entitling': 0.00017346053772766696,
#          'holders': 0.001821335646140503,
#          'monthly': 0.0026019080659150044,
#          'floating': 0.0006938421509106678,
#          'dividends': 0.0013009540329575022,
#          'prime': 0.005377276669557675,
#          'share': 0.03451864700780572,
#          'retraction': 8.673026886383348e-05,
#          'aristech': 0.00026019080659150045,
#          'ars': 8.673026886383348e-05,
#          'st': 0.019340849956634865,
#          'qtr': 0.03235039028620989,
#          'shr': 0.04336513443191674,
#          'estimate': 0.0023417172593235037,
#          'right': 0.0026019080659150044,
#          'chairman': 0.009366869037294015,
#          'chief': 0.002862098872506505,
#          'executive': 0.003469210754553339,
#          'officer': 0.001647875108412836,
#          'thomas': 0.0003469210754553339,
#          'marshall': 0.0007805724197745013,
#          'estimates': 0.003816131830008673,
#          'fiscal': 0.005897658282740676,
#          'earnings': 0.012575888985255855,
#          'about': 0.037033824804856896,
#          'hint': 8.673026886383348e-05,
#          'what': 0.005290546400693842,
#          'announcement': 0.0037294015611448396,
#          'might': 0.00424978317432784,
#          'may': 0.03772766695576756,
#          'buy': 0.011101474414570685,
#          'wheat': 0.012662619254119687,
#          'valued': 0.0009540329575021682,
#          'april': 0.032610581092801384,
#          'august': 0.0026886383347788376,
#          'ship': 0.0012142237640936687,
#          'ports': 0.0013009540329575022,
#          'september': 0.0033824804856895057,
#          'department': 0.012836079791847355,
#          'magellan': 0.0006071118820468344,
#          'did': 0.008065915004336514,
#          'disclose': 0.0010407632263660018,
#          'agreement': 0.01743278404163053,
#          'fees': 0.0011274934952298352,
#          'trust': 0.004076322636600173,
#          'banking': 0.0035559410234171727,
#          'services': 0.0051170858629661755,
#          'rose': 0.016565481352992194,
#          'earlier': 0.011708586296617519,
#          'adams': 0.0003469210754553339,
#          'express': 0.0005203816131830009,
#          'co': 0.02575888985255854,
#          'adx': 8.673026886383348e-05,
#          'march': 0.021335646140503036,
#          'vs': 0.15862966175195142,
#          'shrs': 0.011621856027753686,
#          'out': 0.010320901994796183,
#          'lastest': 8.673026886383348e-05,
#          'capital': 0.007458803122289679,
#          'gain': 0.006938421509106678,
#          'distributions': 0.00026019080659150045,
#          'cts': 0.08673026886383348,
#          'december': 0.006418039895923678,
#          'china': 0.007892454466608847,
#          'resumes': 0.00017346053772766696,
#          'ussr': 0.001474414570685169,
#          'repairs': 0.0004336513443191674,
#          'gap': 0.0006938421509106678,
#          'resumed': 0.0003469210754553339,
#          'soviet': 0.003469210754553339,
#          'break': 0.0012142237640936687,
#          'caused': 0.0027753686036426713,
#          'ideological': 8.673026886383348e-05,
#          'split': 0.005290546400693842,
#          'seasonally': 0.0024284475281873374,
#          'adjusted': 0.006418039895923678,
#          'index': 0.0033824804856895057,
#          'input': 0.0003469210754553339,
#          'prices': 0.026799653078924544,
#          'rise': 0.016912402428447527,
#          'rash': 8.673026886383348e-05,
#          'advertising': 0.0004336513443191674,
#          'solicit': 0.00026019080659150045,
#          'new': 0.03434518647007806,
#          'business': 0.011014744145706851,
#          'helped': 0.0013876843018213356,
#          'homebuyers': 8.673026886383348e-05,
#          'become': 0.003122289679098005,
#          'even': 0.0033824804856895057,
#          'choosier': 8.673026886383348e-05,
#          'loans': 0.008586296617519515,
#          'lenders': 0.0005203816131830009,
#          'concede': 8.673026886383348e-05,
#          'being': 0.006851691240242845,
#          'forced': 0.0011274934952298352,
#          'undercut': 0.00017346053772766696,
#          'each': 0.00823937554206418,
#          'totally': 0.00026019080659150045,
#          'unadjusted': 0.0010407632263660018,
#          'figures': 0.00849956634865568,
#          'show': 0.004423243712055508,
#          'deficit': 0.015611448395490026,
#          'revised': 0.003295750216825672,
#          'compared': 0.011361665221162186,
#          'statistics': 0.002948829141370338,
#          'producer': 0.0039028620988725065,
#          'heavy': 0.002862098872506505,
#          'heating': 0.0011274934952298352,
#          'oil': 0.040156114483954904,
#          'were': 0.042758022549869906,
#          'liquefied': 0.00026019080659150045,
#          'coffee': 0.0051170858629661755,
#          'cheaper': 0.0005203816131830009,
#          'xebec': 0.0005203816131830009,
#          'also': 0.028534258456201216,
#          'expects': 0.007458803122289679,
#          'revenues': 0.005030355594102341,
#          'total': 0.0202081526452732,
#          'ncr': 0.0007805724197745013,
#          'say': 0.006938421509106678,
#          'achieving': 0.00017346053772766696,
#          'recuperation': 0.00017346053772766696,
#          'credit': 0.010147441457068517,
#          'cannot': 0.0019080659150043364,
#          'done': 0.001647875108412836,
#          'overnight': 0.0013876843018213356,
#          'azpurua': 0.0008673026886383347,
#          'television': 0.001821335646140503,
#          'interview': 0.0015611448395490026,
#          'commonwealth': 0.0011274934952298352,
#          'cuts': 0.00598438855160451,
#          'australia': 0.004076322636600173,
#          'lower': 0.011014744145706851,
#          'lending': 0.0012142237640936687,
#          'effective': 0.006157849089332177,
#          'progress': 0.001474414570685169,
#          'all': 0.01769297484822203,
#          'main': 0.002948829141370338,
#          'sectors': 0.001474414570685169,
#          'except': 0.0012142237640936687,
#          'goods': 0.004856895056374675,
#          'where': 0.004509973980919341,
#          'remain': 0.004163052905464007,
#          'present': 0.0026886383347788376,
#          'level': 0.006678230702515177,
#          'report': 0.014657415437987858,
#          'fluor': 0.00026019080659150045,
#          'applied': 0.0008673026886383347,
#          'engineering': 0.0005203816131830009,
#          'construct': 0.00017346053772766696,
#          'modular': 8.673026886383348e-05,
#          'sections': 0.00026019080659150045,
#          'deliver': 0.0004336513443191674,
#          'them': 0.004076322636600173,
#          'ge': 0.0005203816131830009,
#          'waterford': 8.673026886383348e-05,
#          'n': 0.005897658282740676,
#          'y': 0.0013876843018213356,
#          'silicone': 8.673026886383348e-05,
#          'division': 0.004076322636600173,
#          'plant': 0.004770164787510842,
#          'some': 0.018820468343451864,
#          'merchants': 0.0008673026886383347,
#          'fear': 0.0005203816131830009,
#          'large': 0.0051170858629661755,
#          'tonnage': 0.0006071118820468344,
#          'delivered': 0.0006938421509106678,
#          'futures': 0.004423243712055508,
#          'month': 0.017519514310494363,
#          'possibly': 0.0013876843018213356,
#          'disrupt': 8.673026886383348e-05,
#          'physical': 0.0006938421509106678,
#          'franc': 0.001647875108412836,
#          'carries': 0.0005203816131830009,
#          'warrants': 0.0017346053772766695,
#          'today': 0.019514310494362534,
#          'itc': 0.0013876843018213356,
#          'ruling': 0.0022549869904596705,
#          'consistent': 0.0013009540329575022,
#          'commerce': 0.002948829141370338,
#          'final': 0.003469210754553339,
#          'activates': 8.673026886383348e-05,
#          'anti': 0.0013876843018213356,
#          'dumping': 0.0013009540329575022,
#          'duty': 0.0007805724197745013,
#          'imports': 0.016305290546400692,
#          'brazilian': 0.0019080659150043364,
#          'frozen': 0.0010407632263660018,
#          'concentrated': 0.0006071118820468344,
#          'orange': 0.0025151777970511707,
#          'juice': 0.0017346053772766695,
#          'stephen': 0.0005203816131830009,
#          'vastagh': 0.0003469210754553339,
#          'investigator': 8.673026886383348e-05,
#          'ministry': 0.007892454466608847,
#          'tf': 0.00017346053772766696,
#          'forthcoming': 0.00017346053772766696,
#          'sell': 0.009280138768430183,
#          'off': 0.006071118820468344,
#          'meant': 0.0005203816131830009,
#          'third': 0.004856895056374675,
#          'government': 0.020815264527320035,
#          'programme': 0.0009540329575021682,
#          'less': 0.0063313096270598435,
#          'than': 0.02593235039028621,
#          'nine': 0.008586296617519515,
#          'institutes': 0.0026886383347788376,
#          'issued': 0.003295750216825672,
#          'joint': 0.00398959236773634,
#          'spring': 0.001647875108412836,
#          'three': 0.019167389418907197,
#          'kiel': 0.00017346053772766696,
#          'hamburg': 0.0003469210754553339,
#          'essen': 0.00017346053772766696,
#          'forecast': 0.006418039895923678,
#          'gnp': 0.003122289679098005,
#          'west': 0.015351257588898526,
#          'berlin': 0.0006071118820468344,
#          'munich': 0.00026019080659150045,
#          'predicted': 0.0025151777970511707,
#          'one': 0.03616652211621856,
#          'westcoast': 0.00026019080659150045,
#          'enable': 0.0006071118820468344,
#          'apply': 0.0006938421509106678,
#          'accumulated': 0.0003469210754553339,
#          'tax': 0.019340849956634865,
#          'pools': 8.673026886383348e-05,
#          'agip': 0.0007805724197745013,
#          'canada': 0.011014744145706851,
#          'enhance': 0.0005203816131830009,
#          'cash': 0.01118820468343452,
#          'flow': 0.0013009540329575022,
#          'acquired': 0.006678230702515177,
#          'properties': 0.002168256721595837,
#          'proxy': 0.0004336513443191674,
#          'materials': 0.0035559410234171727,
#          'maioled': 8.673026886383348e-05,
#          'this': 0.04588031222896791,
#          'quarter': 0.026973113616652212,
#          'speech': 0.0008673026886383347,
#          'prepared': 0.0017346053772766695,
#          'delivery': 0.00424978317432784,
#          'plans': 0.0075455333911535125,
#          'protect': 0.0019080659150043364,
#          'kuwaiti': 0.001647875108412836,
#          'tankers': 0.0008673026886383347,
#          'iranian': 0.001647875108412836,
#          'attack': 0.0010407632263660018,
#          'reagan': 0.006418039895923678,
#          'people': 0.0024284475281873374,
#          'aware': 0.0003469210754553339,
#          'our': 0.007285342584562012,
#          'interests': 0.002948829141370338,
#          'alone': 0.0007805724197745013,
#          'protected': 0.0008673026886383347,
#          'pointed': 0.0005203816131830009,
#          'depressed': 0.0006938421509106678,
#          'reason': 0.002168256721595837,
#          'current': 0.01647875108412836,
#          'weakness': 0.0013876843018213356,
#          'economy': 0.009540329575021683,
#          'later': 0.00424978317432784,
#          'stronger': 0.0006071118820468344,
#          'domestic': 0.01118820468343452,
#          'demand': 0.011361665221162186,
#          'compensate': 0.0004336513443191674,
#          'setback': 8.673026886383348e-05,
#          'happy': 0.0003469210754553339,
#          'brought': 0.0008673026886383347,
#          'forward': 0.0020815264527320036,
#          'marks': 0.005897658282740676,
#          'planned': 0.003642671292281006,
#          'january': 0.007632263660017346,
#          'beginning': 0.0020815264527320036,
#          'faced': 0.0004336513443191674,
#          'political': 0.0024284475281873374,
#          'constraints': 0.0004336513443191674,
#          'getting': 0.0006938421509106678,
#          'such': 0.007025151777970512,
#          'through': 0.00797918473547268,
#          'upper': 0.0006938421509106678,
#          'house': 0.00572419774501301,
#          'german': 0.00797918473547268,
#          'parliament': 0.0004336513443191674,
#          'quoted': 0.0026019080659150044,
#          'stg': 0.015264527320034691,
#          'midsession': 0.00017346053772766696,
#          'figure': 0.0037294015611448396,
#          'represents': 0.0008673026886383347,
#          'decline': 0.005290546400693842,
#          'buffer': 0.0025151777970511707,
#          'aims': 0.0003469210754553339,
#          'keep': 0.0025151777970511707,
#          'within': 0.004163052905464007,
#          'pre': 0.0020815264527320036,
#          'set': 0.006504770164787511,
#          'range': 0.0039028620988725065,
#          'buying': 0.003816131830008673,
#          'when': 0.01248915871639202,
#          'selling': 0.0026019080659150044,
#          'bentsen': 0.0004336513443191674,
#          'coordinated': 0.00017346053772766696,
#          'billions': 8.673026886383348e-05,
#          'debt': 0.009366869037294015,
#          'service': 0.002862098872506505,
#          'latin': 0.0003469210754553339,
#          'help': 0.00598438855160451,
#          'ease': 0.001474414570685169,
#          'protectionist': 0.0013009540329575022,
#          'pressures': 0.0013009540329575022,
#          'industrial': 0.00797918473547268,
#          'proposal': 0.006591500433651344,
#          'objectives': 0.0004336513443191674,
#          'maintain': 0.0025151777970511707,
#          'import': 0.004770164787510842,
#          'levels': 0.0063313096270598435,
#          'idc': 0.0003469210754553339,
#          'official': 0.011708586296617519,
#          'declined': 0.004163052905464007,
#          'specify': 0.0005203816131830009,
#          'up': 0.02714657415437988,
#          'talks': 0.007632263660017346,
#          'economists': 0.004596704249783174,
#          'spending': 0.003295750216825672,
#          'target': 0.00398959236773634,
#          'rand': 0.0007805724197745013,
#          'revenue': 0.0020815264527320036,
#          'budgeted': 0.0003469210754553339,
#          'around': 0.011621856027753686,
#          'validly': 0.0003469210754553339,
#          'tendered': 0.0015611448395490026,
#          'represented': 0.0006071118820468344,
#          'outstanding': 0.007285342584562012,
#          'supermarkets': 0.0007805724197745013,
#          'general': 0.006678230702515177,
#          'america': 0.00398959236773634,
#          'retain': 0.0006938421509106678,
#          'refusal': 0.0003469210754553339,
#          'if': 0.019861231569817867,
#          'ansett': 0.0006938421509106678,
#          'offered': 0.003642671292281006,
#          'sale': 0.009280138768430183,
#          'choke': 0.00017346053772766696,
#          'modest': 0.001821335646140503,
#          'economic': 0.017085862966175196,
#          'expansion': 0.0025151777970511707,
#          'threaten': 0.0003469210754553339,
#          'recession': 0.0013009540329575022,
#          'bought': 0.006071118820468344,
#          'band': 0.0013009540329575022,
#          'eight': 0.007025151777970512,
#          'four': 0.012575888985255855,
#          'paid': 0.004596704249783174,
#          'assumption': 0.0008673026886383347,
#          'liabilities': 0.0006071118820468344,
#          'maize': 0.002948829141370338,
#          'sown': 0.0008673026886383347,
#          'hectares': 0.0020815264527320036,
#          'season': 0.004856895056374675,
#          'hopefully': 0.00017346053772766696,
#          'trend': 0.0009540329575021682,
#          'richardson': 0.00017346053772766696,
#          'greenshields': 8.673026886383348e-05,
#          'economist': 0.0022549869904596705,
#          'susan': 8.673026886383348e-05,
#          'clark': 0.0006938421509106678,
#          'toronto': 0.0007805724197745013,
#          'investment': 0.011014744145706851,
#          'firm': 0.007805724197745013,
#          'raises': 0.0046834345186470075,
#          'tvx': 0.00026019080659150045,
#          'tvxg': 0.00017346053772766696,
#          'o': 0.021335646140503036,
#          'stake': 0.011014744145706851,
#          'wedge': 8.673026886383348e-05,
#          'inc': 0.050043365134431916,
#          'houston': 0.0013009540329575022,
#          'raised': 0.004423243712055508,
#          'broadcast': 0.0004336513443191674,
#          'common': 0.010841283607979185,
#          'calls': 0.002168256721595837,
#          'sino': 8.673026886383348e-05,
#          'chilean': 8.673026886383348e-05,
#          'venture': 0.003122289679098005,
#          'paper': 0.001821335646140503,
#          'european': 0.009019947961838682,
#          'mediterranean': 0.00026019080659150045,
#          'area': 0.00398959236773634,
#          'rig': 0.0003469210754553339,
#          'utilization': 0.00026019080659150045,
#          'ago': 0.009366869037294015,
#          'upset': 8.673026886383348e-05,
#          'compounded': 8.673026886383348e-05,
#          'news': 0.003816131830008673,
#          'sterling': 0.0015611448395490026,
#          'above': 0.004596704249783174,
#          'england': 0.0027753686036426713,
#          'looks': 0.0008673026886383347,
#          'likely': 0.007458803122289679,
#          'gilts': 0.00017346053772766696,
#          'offset': 0.0022549869904596705,
#          'impact': 0.00398959236773634,
#          'money': 0.012749349522983521,
#          'supply': 0.010320901994796183,
#          'bp': 0.0013009540329575022,
#          'cut': 0.014310494362532523,
#          'came': 0.0015611448395490026,
#          'result': 0.005810928013876843,
#          'review': 0.002948829141370338,
#          'occasioned': 8.673026886383348e-05,
#          'substantial': 0.0026886383347788376,
#          'changes': 0.003035559410234172,
#          'lpg': 0.00017346053772766696,
#          'congressional': 0.00199479618386817,
#          'leaders': 0.0012142237640936687,
#          'complain': 8.673026886383348e-05,
#          'consulted': 0.00017346053772766696,
#          'put': 0.004423243712055508,
#          'flag': 0.0007805724197745013,
#          'charged': 0.0007805724197745013,
#          'lead': 0.00598438855160451,
#          'into': 0.012836079791847355,
#          'iran': 0.0019080659150043364,
#          'iraq': 0.0027753686036426713,
#          'war': 0.002168256721595837,
#          'told': 0.01717259323503903,
#          'al': 0.0006071118820468344,
#          'riyadh': 0.00026019080659150045,
#          'newspaper': 0.0025151777970511707,
#          'saudi': 0.003295750216825672,
#          'arabia': 0.0022549869904596705,
#          'follows': 0.002948829141370338,
#          'balanced': 0.0006071118820468344,
#          'petroleum': 0.0063313096270598435,
#          'expanded': 0.0005203816131830009,
#          'baht': 0.00026019080659150045,
#          'deputy': 0.0010407632263660018,
#          'representative': 0.001474414570685169,
#          'michael': 0.0009540329575021682,
#          'smith': 0.0007805724197745013,
#          'makoto': 0.00017346053772766696,
#          'kuroda': 0.0005203816131830009,
#          'minister': 0.008846487424111016,
#          'international': 0.016045099739809193,
#          'industry': 0.013876843018213356,
#          'miti': 0.0010407632263660018,
#          'due': 0.011274934952298352,
#          'meet': 0.004163052905464007,
#          'washington': 0.006071118820468344,
#          'week': 0.024804856895056376,
#          'effort': 0.0022549869904596705,
#          'dispute': 0.0015611448395490026,
#          'legislation': 0.0017346053772766695,
#          'supported': 0.0007805724197745013,
#          'congress': 0.0033824804856895057,
#          'democratic': 0.0013876843018213356,
#          'republican': 0.0003469210754553339,
#          'leadership': 0.00026019080659150045,
#          'administration': 0.003035559410234172,
#          'required': 0.0020815264527320036,
#          'defense': 0.0020815264527320036,
#          'secretary': 0.0035559410234171727,
#          'caspar': 8.673026886383348e-05,
#          'weinberger': 8.673026886383348e-05,
#          'provide': 0.0027753686036426713,
#          'days': 0.010494362532523852,
#          'enactment': 8.673026886383348e-05,
#          'warships': 0.00026019080659150045,
#          'persian': 8.673026886383348e-05,
#          'gulf': 0.00624457935819601,
#          'questioned': 0.0003469210754553339,
#          'whether': 0.003035559410234172,
#          'based': 0.010060711188204683,
#          'entertainment': 0.0013009540329575022,
#          'marketing': 0.004943625325238508,
#          'founded': 0.00026019080659150045,
#          'former': 0.0019080659150043364,
#          'electronics': 0.0017346053772766695,
#          'retailer': 0.0005203816131830009,
#          'buinesses': 8.673026886383348e-05,
#          'primarily': 0.0008673026886383347,
#          'wholesale': 0.0012142237640936687,
#          'distributors': 0.0005203816131830009,
#          'expertise': 8.673026886383348e-05,
#          'retailing': 0.0004336513443191674,
#          'merely': 0.00026019080659150045,
#          'trying': 0.0017346053772766695,
#          'drive': 0.001474414570685169,
#          'crazy': 0.0026019080659150044,
#          'eddie': 0.0026886383347788376,
#          'already': 0.00572419774501301,
#          'owns': 0.002862098872506505,
#          'federal': 0.009887250650477016,
#          'reserve': 0.007632263660017346,
#          'board': 0.01196877710320902,
#          'paul': 0.0013009540329575022,
#          'volcker': 0.0017346053772766695,
#          'repeatedly': 0.0006071118820468344,
#          'cutting': 0.001474414570685169,
#          'red': 0.0019080659150043364,
#          'ink': 0.00026019080659150045,
#          'long': 0.007805724197745013,
#          'way': 0.003035559410234172,
#          'reduce': 0.005550737207285343,
#          'massive': 0.0009540329575021682,
#          'downward': 0.0008673026886383347,
#          'pressure': 0.003816131830008673,
#          'value': 0.006851691240242845,
#          'profit': 0.023417172593235037,
#          'almost': 0.002168256721595837,
#          'consolidated': 0.0020815264527320036,
#          'net': 0.07649609713790113,
#          'swiss': 0.002948829141370338,
#          'francs': 0.004596704249783174,
#          'drop': 0.003816131830008673,
#          'cardenas': 0.00017346053772766696,
#          'cents': 0.00598438855160451,
#          'lb': 0.0013876843018213356,
#          'october': 0.0039028620988725065,
#          'support': 0.004770164787510842,
#          'jorge': 0.00017346053772766696,
#          'manager': 0.003295750216825672,
#          'colombia': 0.0015611448395490026,
#          'national': 0.012575888985255855,
#          'growers': 0.0009540329575021682,
#          'federation': 0.0011274934952298352,
#          'little': 0.004336513443191674,
#          'reaction': 0.0010407632263660018,
#          'comex': 0.0004336513443191674,
#          'limit': 0.0027753686036426713,
#          'removal': 0.0007805724197745013,
#          'elimination': 0.0006071118820468344,
#          'limits': 0.0008673026886383347,
#          'precious': 0.0003469210754553339,
#          'metals': 0.0013876843018213356,
#          'contracts': 0.0023417172593235037,
#          'trading': 0.010928013876843019,
#          'commodity': 0.003642671292281006,
#          'exchange': 0.01847354726799653,
#          'york': 0.006504770164787511,
#          'appears': 0.0010407632263660018,
#          'effect': 0.003035559410234172,
#          'mercer': 0.0005203816131830009,
#          'operating': 0.0067649609713790115,
#          'goodyear': 0.0012142237640936687,
#          'repurchase': 0.0037294015611448396,
#          'fend': 0.00026019080659150045,
#          'sir': 0.0003469210754553339,
#          'goldsmith': 0.0003469210754553339,
#          'hostile': 0.0012142237640936687,
#          'takeover': 0.006678230702515177,
#          'bid': 0.009366869037294015,
#          'lot': 0.0010407632263660018,
#          'given': 0.004596704249783174,
#          'lindberg': 8.673026886383348e-05,
#          'lind': 8.673026886383348e-05,
#          'sales': 0.026105810928013878,
#          'avg': 0.011535125758889852,
#          'proceeds': 0.002168256721595837,
#          'property': 0.0013009540329575022,
#          'discount': 0.004509973980919341,
#          'penalty': 0.00026019080659150045,
#          'rather': 0.0020815264527320036,
#          'guiding': 0.00017346053772766696,
#          'since': 0.010147441457068517,
#          'advances': 0.0004336513443191674,
#          'currently': 0.004163052905464007,
#          'used': 0.005203816131830009,
#          'liquidity': 0.0020815264527320036,
#          'ample': 0.0003469210754553339,
#          'traders': 0.009280138768430183,
#          'london': 0.004336513443191674,
#          'outcome': 0.0008673026886383347,
#          'tender': 0.010234171725932351,
#          'hard': 0.0024284475281873374,
#          'predict': 0.0005203816131830009,
#          'award': 0.0006071118820468344,
#          'placing': 0.0005203816131830009,
#          'borg': 0.0035559410234171727,
#          'warner': 0.003816131830008673,
#          'participant': 8.673026886383348e-05,
#          'managers': 0.0006071118820468344,
#          'their': 0.01569817866435386,
#          'positions': 0.0013876843018213356,
#          'reuter': 0.001821335646140503,
#          'k': 0.007285342584562012,
#          'assistance': 0.001474414570685169,
#          'provided': 0.001647875108412836,
#          'morning': 0.0027753686036426713,
#          'session': 0.001647875108412836,
#          'takashi': 0.0003469210754553339,
#          'ishihara': 0.0005203816131830009,
#          'committee': 0.005290546400693842,
#          'development': 0.006418039895923678,
#          'accord': 0.00398959236773634,
#          'prevent': 0.0020815264527320036,
#          'rising': 0.005203816131830009,
#          'further': 0.012142237640936688,
#          'extent': 0.0006071118820468344,
#          'fewer': 0.0008673026886383347,
#          'sdhares': 8.673026886383348e-05,
#          'offer': 0.02246313963573287,
#          'stockholders': 0.001647875108412836,
#          'receive': 0.003642671292281006,
#          'combination': 0.0013009540329575022,
#          'caesars': 0.0007805724197745013,
#          'unilever': 0.0008673026886383347,
#          'seeks': 0.0012142237640936687,
#          'buyer': 0.0013876843018213356,
#          'stauffer': 0.0004336513443191674,
#          'nv': 0.0005203816131830009,
#          'un': 0.00026019080659150045,
#          'prospectus': 0.00017346053772766696,
#          'bankers': 0.004596704249783174,
#          'goldman': 0.00017346053772766696,
#          'sachs': 0.00017346053772766696,
#          'seeking': 0.003122289679098005,
#          'recent': 0.006678230702515177,
#          'chesebrough': 0.0004336513443191674,
#          ...})

# %%
# Let's transform the counts to probabilities
for w1_w2 in model:
    total_count = float(sum(model[w1_w2].values()))
    for w3 in model[w1_w2]:
        model[w1_w2][w3] /= total_count

# %%
# predict the next word
dict(model["oil", "supply"])
# Out:
# {'pct': 0.125,
#  'line': 0.125,
#  'group': 0.125,
#  'bi': 0.125,
#  'demand': 0.125,
#  'jeapordy': 0.125,
#  'total': 0.125,
#  'key': 0.125}

# %%
# another example
dict(model["increase", "the"])
# Out:
# {}

# %%
# another example
dict(model["a", "step"])
# Out:
# {}

# %%
# another example
dict(model["last", "year"])
# Out:
# {'five': 0.00641025641025641,
#  'fend': 0.00641025641025641,
#  "'": 0.16025641025641027,
#  'bag': 0.00641025641025641,
#  'index': 0.00641025641025641,
#  'billion': 0.038461538461538464,
#  'west': 0.00641025641025641,
#  'offer': 0.00641025641025641,
#  'processing': 0.02564102564102564,
#  'necessarily': 0.00641025641025641,
#  'temporary': 0.00641025641025641,
#  'tokyo': 0.019230769230769232,
#  'imbalance': 0.00641025641025641,
#  'domestic': 0.01282051282051282,
#  'rise': 0.00641025641025641,
#  'cpc': 0.00641025641025641,
#  'first': 0.00641025641025641,
#  'national': 0.00641025641025641,
#  'predicted': 0.00641025641025641,
#  'expects': 0.01282051282051282,
#  'merchant': 0.00641025641025641,
#  'higher': 0.00641025641025641,
#  'earned': 0.01282051282051282,
#  'record': 0.00641025641025641,
#  'said': 0.038461538461538464,
#  'april': 0.00641025641025641,
#  'ended': 0.00641025641025641,
#  'allegis': 0.00641025641025641,
#  'compared': 0.00641025641025641,
#  'paid': 0.01282051282051282,
#  'bank': 0.01282051282051282,
#  'difficulty': 0.01282051282051282,
#  'fewer': 0.00641025641025641,
#  'shipment': 0.00641025641025641,
#  'according': 0.00641025641025641,
#  'major': 0.019230769230769232,
#  'figure': 0.019230769230769232,
#  'import': 0.00641025641025641,
#  'mln': 0.03205128205128205,
#  'spokesman': 0.00641025641025641,
#  'proposed': 0.00641025641025641,
#  'tonne': 0.00641025641025641,
#  'opec': 0.00641025641025641,
#  'cia': 0.00641025641025641,
#  'including': 0.01282051282051282,
#  'south': 0.01282051282051282,
#  'mainly': 0.00641025641025641,
#  'study': 0.00641025641025641,
#  'one': 0.01282051282051282,
#  'take': 0.00641025641025641,
#  'shifting': 0.00641025641025641,
#  'end': 0.00641025641025641,
#  'federal': 0.01282051282051282,
#  'world': 0.00641025641025641,
#  'pegged': 0.00641025641025641,
#  'led': 0.00641025641025641,
#  'total': 0.00641025641025641,
#  'continued': 0.00641025641025641,
#  'well': 0.00641025641025641,
#  'ldp': 0.00641025641025641,
#  'barley': 0.00641025641025641,
#  'even': 0.00641025641025641,
#  'target': 0.00641025641025641,
#  'made': 0.01282051282051282,
#  'reaching': 0.00641025641025641,
#  'contracting': 0.00641025641025641,
#  'dominion': 0.00641025641025641,
#  'pct': 0.01282051282051282,
#  'took': 0.00641025641025641,
#  'along': 0.00641025641025641,
#  'however': 0.00641025641025641,
#  'barter': 0.00641025641025641,
#  'division': 0.00641025641025641,
#  'baker': 0.00641025641025641,
#  'budget': 0.00641025641025641,
#  'less': 0.00641025641025641,
#  'worth': 0.00641025641025641,
#  'seven': 0.00641025641025641,
#  'vetoed': 0.00641025641025641,
#  'reflecting': 0.00641025641025641,
#  'canadian': 0.00641025641025641,
#  'hong': 0.00641025641025641,
#  'new': 0.00641025641025641,
#  'reached': 0.00641025641025641,
#  'include': 0.00641025641025641,
#  'stood': 0.00641025641025641,
#  'would': 0.00641025641025641,
#  'two': 0.00641025641025641,
#  'expected': 0.00641025641025641,
#  'jumped': 0.00641025641025641,
#  'provisional': 0.00641025641025641,
#  'residual': 0.00641025641025641,
#  'show': 0.00641025641025641,
#  'atrocious': 0.01282051282051282,
#  'copper': 0.00641025641025641,
#  'holding': 0.00641025641025641}

# %%
#calsulate the perplexity of the model using the training dataset
import math

def calculate_perplexity(dataset, trigram_model):
    log_prob_sum = 0
    total_words = 0

    for sentence in dataset['Sentences']:
        trigram_list = create_trigram(sentence)

        for w1, w2, w3 in trigram_list:
            # Get the probability of word w3 given the bigram (w1, w2)
            if trigram_model[(w1, w2)]:
                prob = trigram_model[(w1, w2)].get(w3, 0)
                if prob > 0:
                    log_prob_sum += math.log2(prob)
                    total_words += 1

    # Calculate the cross-entropy
    if total_words > 0:
        cross_entropy = -log_prob_sum / total_words
        # Calculate perplexity
        perplexity = math.pow(2, cross_entropy)
        return perplexity
    else:
        return float('inf')


perplexity = calculate_perplexity(dataset, model)
print(f"Perplexity: {perplexity}")
# Out:
# Perplexity: 3.198650811720578

# %%
##calculate the perplexity of the model on the testing dataset
import math

def calculate_perplexity(dataset, trigram_model):
    log_prob_sum = 0
    total_words = 0

    for sentence in dataset:
        trigram_list = create_trigram(sentence)

        for w1, w2, w3 in trigram_list:
            # Get the probability of word w3 given the bigram (w1, w2)
            if trigram_model[(w1, w2)]:
                prob = trigram_model[(w1, w2)].get(w3, 0)
                if prob > 0:
                    log_prob_sum += math.log2(prob)
                    total_words += 1

    # Calculate the cross-entropy
    if total_words > 0:
        cross_entropy = -log_prob_sum / total_words
        # Calculate perplexity
        perplexity = math.pow(2, cross_entropy)
        return perplexity
    else:
        return float('inf')


perplexity = calculate_perplexity(test_sentences, model)
print(f"Perplexity: {perplexity}")
# Out:
# Perplexity: 4.3811406319724435
